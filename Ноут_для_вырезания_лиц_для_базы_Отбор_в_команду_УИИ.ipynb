# %% [markdown]
# <a href="https://colab.research.google.com/github/Mike030668/Class_test/blob/master/%D0%9D%D0%BE%D1%83%D1%82_%D0%B4%D0%BB%D1%8F_%D0%B2%D1%8B%D1%80%D0%B5%D0%B7%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BB%D0%B8%D1%86_%D0%B4%D0%BB%D1%8F_%D0%B1%D0%B0%D0%B7%D1%8B_%D0%9E%D1%82%D0%B1%D0%BE%D1%80_%D0%B2_%D0%BA%D0%BE%D0%BC%D0%B0%D0%BD%D0%B4%D1%83_%D0%A3%D0%98%D0%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)

# %%
import numpy as np
from PIL import Image, ImageDraw, ImageFont # Модули работы с изображениями

# %%
image_path = '/content/drive/MyDrive/Colab Bases/Команда УИИ/Test Kerry/'+idx
image_base = cv2.imread(image_path)
image = cv2.imread(image_path)

# %%
import cv2
import os
from google.colab.patches import cv2_imshow



path = os.path.join(cv2.data.haarcascades, 'haarcascade_frontalface_default.xml')
face_cascade = cv2.CascadeClassifier( path )

idx = np.random.choice(frameID)

image_path = '/content/drive/MyDrive/Colab Bases/Команда УИИ/Test Kerry/'+idx
image_base = cv2.imread(image_path)
image = cv2.imread(image_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor= 1.1,
    minNeighbors= 5,
    minSize=(10, 10)
)
faces_detected = "Лиц обнаружено: " + format(len(faces))
print(faces_detected)
# Рисуем квадраты вокруг лиц
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (255, 255, 0), 2)
cv2_imshow(image)

#cv2_imshow(image_base[y:y+h,x:x+w,:])
path_save = '/content/drive/MyDrive/Colab Bases/Команда УИИ/Face_Kerry/' + idx

face_np = image_base[y:y+h,x:x+w,:]

face_img = Image.fromarray(face_np) #cv2_imshow(face_np) # cv2.imwrite(face_np) #path_save)#
face_img = face_img.resize((216, 216)) 
face_np = np.array(face_img)
cv2.imwrite(path_save, face_np)##
# Out:
# Лиц обнаружено: 1
# <PIL.Image.Image image mode=RGB size=768x480 at 0x7FB169AC4E50>
# True

# %% [markdown]
# # Вырезания лиц для создания контрольной базы лиц

# %%
import cv2
import os
from google.colab.patches import cv2_imshow

path = os.path.join(cv2.data.haarcascades, 'haarcascade_frontalface_default.xml')
face_cascade = cv2.CascadeClassifier( path )

# %%
from google.colab.patches import cv2_imshow
import cv2
import time
path_test_video = '/content/drive/MyDrive/Colab Bases/Команда УИИ/Shou_Trumana_Kinosimka.RU (online-video-cutter.com).mp4'
cap = cv2.VideoCapture(path_test_video)

start = time.time()

np_cutfilm = []
all_persons = []
cadr = 0
while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    if not ret:
      break

    if cadr%2== 0:
      image_base = frame
      gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
      faces = face_cascade.detectMultiScale(
          gray,
          scaleFactor= 1.1,
          minNeighbors= 5,
          minSize=(10, 10)
      )

      # Рисуем квадраты вокруг лиц
      for i,(x, y, w, h) in enumerate(faces):
          cv2.rectangle(faces, (x, y), (x+w, y+h), (255, 255, 0), 2)

          path_save = '/content/drive/MyDrive/Colab Bases/Команда УИИ/Face_Kerry/' + str(cadr)+'_'+str(i) + '.jpg'

          face_np = image_base[y:y+h,x:x+w,:]

          face_img = Image.fromarray(face_np) #cv2_imshow(face_np) # cv2.imwrite(face_np) #path_save)#
          face_img = face_img.resize((128, 128)) 
          face_np = np.array(face_img)
          cv2.imwrite(path_save, face_np)##
    cadr+=1
          
    cv2.waitKey(1) & 0xFF

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()

finish = time.time() - start
print('время обработки', finish)

# %% [markdown]
# # Загрузка отобранной базы контрольных лиц

# %%
# Глобальные параметры
img_width = 128 # Ширина уменьшенной картинки 
img_height = 128 # Высота уменьшенной картинки 

directory = '/content/drive/MyDrive/Colab Bases/Команда УИИ/Face_Kerry/' # Указываем путь к обучающей выборке с оригинальными изображения

# %%
from tensorflow.keras.preprocessing import image # Импортируем модуль image для работы с изображениями
cur_time = time.time() # Засекаем текущее время
train_images = []
for filename in sorted(os.listdir(directory)): # Проходим по всем файлам в каталоге по указанному пути     
    train_images.append(image.load_img(os.path.join(directory,filename), color_mode='rgb',
                                          target_size=(img_width, img_height))) # Читаем очередную картинку и добавляем ее в список изображения с указанным target_size           
print ('Выборка загржена. Время загрузки: ', round(time.time() - cur_time, 2), 'c', sep='') # Отображаем время загрузки картинок проверочной выборки
# Out:
# Выборка загржена. Время загрузки: 190.12c

# %%
len(train_images)
# Out:
# 312

# %%
data = []
for img in train_images:
    x = image.img_to_array(img) # Переводим изображение в numpy-массив размерностью: высота - ширина - количество каналов
    data.append(x) # Добавляем очередной элемент в xTrain

x_data = np.array(data) # Переводим в numpy
x_data = x_data / 255. # Трансофрмируем значение в диапазон от -1 до 1
x_data.shape
# Out:
# (312, 128, 128, 3)

# %%
from sklearn.model_selection import train_test_split #Разбиение на обучающую и проверочную выборку
xTrain, xVal = train_test_split(x_data, test_size=0.2)

# %% [markdown]
# #Собираем модель АС

# %%
from tensorflow.keras.models import Sequential, Model  # грузим сеть прямого распространения
#базовые слои сверточных сетей
from tensorflow.keras.layers import UpSampling2D, Dense, Flatten, Reshape, Input, Conv2DTranspose, concatenate, Activation, MaxPooling2D, Conv2D, BatchNormalization, Dropout
#from tensorflow.python.keras.preprocessing.image import ImageDataGenerator #модуль для работы с изображениями
from tensorflow.keras.optimizers import Adam, Adamax, Adadelta # оптимизаторы
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping   # подключаем колбэки

from tensorflow.keras.utils import plot_model #модуль отрисоки структуры нейронки
from tensorflow.keras import utils # метод для to_catagorical
import matplotlib.pyplot as plt # Отображение графиков

# %%
def model_A(shape=(128,128,3)): # зададим функцию создания базового автокодировщика
    img_input = Input((shape)) # задаём входные размеры

    A = Conv2D(32, (3, 3), padding='same', activation='relu')(img_input) # входные данные передаем на слой двумерной свёртки и получаем (112,80,32)
    A = BatchNormalization()(A) # затем пропускаем через слой нормализации данных 
    A = Conv2D(32, (3, 3), strides=(1, 1), padding='same', activation='relu')(A) #(110,78,32) (in_size + 2 * padding_size-filter_size) / stride + 1) 
    A = BatchNormalization()(A) # и еще слой нормализации данных
    A = Conv2D(32, (2, 2), strides=(2, 2), padding='valid', activation='relu')(A) #(55,39,32) (in_size + 2 * padding_size-filter_size) / stride + 1) 
    A = BatchNormalization()(A) # и еще слой нормализации данных

    out_1 = Conv2D(32, (1, 1), strides=(2, 2), padding='same', activation='relu')(A) #(28,20,32) (in_size + 2 * padding_size-filter_size) / stride + 1) 
    print(out_1.shape)
    Z = Flatten()(out_1)
    print(Z.shape)
    out_2 = Dense(100, activation='sigmoid')(Z)
    print(out_2.shape)
    up = Dense(32768, activation='relu')(out_2)
    up = Reshape((32,32,32))(up)
    up = Conv2D(32, (1, 1),  padding='same', activation='relu')(up)
    out_1 = out_1 + up
    model = Model(img_input, [out_1, out_2]) 
    return model # функция вернёт заданную модель

# %%
main_model = model_A((img_width, img_height,3))
# Out:
# (None, 32, 32, 32)
# (None, 32768)
# (None, 100)

# %%
main_model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_16 (InputLayer)           [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 128, 128, 32) 896         input_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 128, 128, 32) 128         conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 128, 128, 32) 9248        batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 128, 128, 32) 128         conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 64, 64, 32)   4128        batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 64, 64, 32)   128         conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 32, 32, 32)   1056        batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 32768)        0           conv2d_61[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 100)          3276900     flatten_10[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 32768)        3309568     dense_20[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 32, 32, 32)   0           dense_21[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 32, 32, 32)   1056        reshape_10[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_9 (TFOpLam (None, 32, 32, 32)   0           conv2d_61[0][0]
#                                                                  conv2d_62[0][0]
# ==================================================================================================
# Total params: 6,603,236
# Trainable params: 6,603,044
# Non-trainable params: 192
# __________________________________________________________________________________________________

# %%
plot_model(main_model, show_shapes=True)

# %%
def model_B(shape=(32,32,32)): # зададим функцию создания базового автокодировщика
    img_input = Input((shape)) # задаём входные размеры
    E = Conv2DTranspose(64, kernel_size=(2, 2), strides=(2, 2), padding='same', activation='relu')(img_input) # слой разжимает данные с (28*20 на 56*40, 64)
    E = BatchNormalization()(E) # слой нормализации данных
    E = Conv2D(64, (3, 3), padding='same', activation='relu')(E) # передаем на слой двумерной свёртки (56*40, 40)
    E = BatchNormalization()(E) # слой нормализации данных
    E = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='valid', activation='relu')(E) # слой разжимает данные (с 56*40 на 112*80, 64)
    E = BatchNormalization()(E) # слой нормализации данных
    E = Conv2D(32, (3, 3), padding='same', activation='relu')(E) # ещё слой двумерной свёртки (112, 80 , 64)
    E = BatchNormalization()(E) # слой нормализации данных

    # Финальный слой двумерной свертки, выдающий итоговое изображение
    X = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(E)  #(112, 80, 1)

    model = Model(img_input, X) # указываем модель, с оригинальным изображением на входе в сеть и сжатым-разжатым на выходе из сети

    return model # функция вернёт заданную модель

# %%
add_model = model_B((32,32,32))

# %%
add_model.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        [(None, 32, 32, 32)]      0
# _________________________________________________________________
# conv2d_transpose_6 (Conv2DTr (None, 64, 64, 64)        8256
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 128, 128, 64)      16448
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 128, 128, 64)      256
# _________________________________________________________________
# conv2d_64 (Conv2D)           (None, 128, 128, 32)      18464
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 128, 128, 32)      128
# _________________________________________________________________
# conv2d_65 (Conv2D)           (None, 128, 128, 3)       867
# =================================================================
# Total params: 81,859
# Trainable params: 81,411
# Non-trainable params: 448
# _________________________________________________________________

# %%
plot_model(add_model, show_shapes=True)

# %%
input_img = Input(shape=(img_width,img_height,3)) # Создаем слой Input 
space_in = main_model(input_img)[0]
out_img = add_model(space_in)
train_model = Model(input_img, out_img)

# %%
train_model.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_18 (InputLayer)        [(None, 128, 128, 3)]     0
# _________________________________________________________________
# model_7 (Functional)         [(None, 32, 32, 32), (Non 6603236
# _________________________________________________________________
# model_8 (Functional)         (None, 128, 128, 3)       81859
# =================================================================
# Total params: 6,685,095
# Trainable params: 6,684,455
# Non-trainable params: 640
# _________________________________________________________________

# %%
plot_model(train_model)

# %% [markdown]
# # Fit() моделей

# %%
 train_model.compile(optimizer=Adam(lr=0.0001), loss='mse', metrics=['accuracy']) # компилируем модель также, с выбором оптимайзера и среднеквадратичной ошибки
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
epochs = 15  # число эпох для обучения
patienceStop = round(epochs/5)  #через сколько эпох остановим обучение, если нет развития
patienceReduce = round(epochs/25) #через сколько эпох понизим lr (шаг обучения)
# функция для колбека по понижению lr
reduce_lr = ReduceLROnPlateau(verbose=1, monitor='val_loss',patience=patienceReduce,min_lr=0.000001,factor=0.3)
# функция для остановки обучения и сохранения лучших весов
earlystopper = EarlyStopping(patience=patienceStop, verbose=1, monitor='val_loss',restore_best_weights=True)

# %%
#обучаем сеть
result = train_model.fit(xTrain, xTrain,
                   batch_size=36,
                   epochs = epochs,
                   validation_data=(xVal, xVal),
                   verbose=1,
                   callbacks=[reduce_lr, earlystopper]) # добавляем наши колбеки
# Out:
# Epoch 1/15
# 7/7 [==============================] - 48s 7s/step - loss: 0.1279 - accuracy: 0.3236 - val_loss: 0.0874 - val_accuracy: 0.2611
# Epoch 2/15
# 7/7 [==============================] - 46s 7s/step - loss: 0.1057 - accuracy: 0.3495 - val_loss: 0.0859 - val_accuracy: 0.4773
# Epoch 3/15
# 7/7 [==============================] - 46s 7s/step - loss: 0.0901 - accuracy: 0.3603 - val_loss: 0.0832 - val_accuracy: 0.4831
# Epoch 4/15
# 7/7 [==============================] - 46s 7s/step - loss: 0.0780 - accuracy: 0.3661 - val_loss: 0.0796 - val_accuracy: 0.4830
# Epoch 5/15
# 7/7 [==============================] - 46s 7s/step - loss: 0.0693 - accuracy: 0.3758 - val_loss: 0.0757 - val_accuracy: 0.5041
# Epoch 6/15
# 7/7 [==============================] - 46s 7s/step - loss: 0.0621 - accuracy: 0.3858 - val_loss: 0.0719 - val_accuracy: 0.6718
# Epoch 7/15
# 7/7 [==============================] - 46s 7s/step - loss: 0.0571 - accuracy: 0.3950 - val_loss: 0.0679 - val_accuracy: 0.7115
# Epoch 8/15
# 7/7 [==============================] - 46s 7s/step - loss: 0.0521 - accuracy: 0.4063 - val_loss: 0.0641 - val_accuracy: 0.7119
# Epoch 9/15
# 7/7 [==============================] - 46s 7s/step - loss: 0.0488 - accuracy: 0.4205 - val_loss: 0.0605 - val_accuracy: 0.7119
# Epoch 10/15
# 7/7 [==============================] - 46s 7s/step - loss: 0.0457 - accuracy: 0.4355 - val_loss: 0.0569 - val_accuracy: 0.7120
# Epoch 11/15
# 7/7 [==============================] - 46s 7s/step - loss: 0.0427 - accuracy: 0.4556 - val_loss: 0.0539 - val_accuracy: 0.7123
# Epoch 12/15
# 7/7 [==============================] - 46s 7s/step - loss: 0.0408 - accuracy: 0.4753 - val_loss: 0.0511 - val_accuracy: 0.7937
# Epoch 13/15
# 7/7 [==============================] - 46s 7s/step - loss: 0.0380 - accuracy: 0.5023 - val_loss: 0.0484 - val_accuracy: 0.8857
# Epoch 14/15
# 7/7 [==============================] - 46s 7s/step - loss: 0.0361 - accuracy: 0.5228 - val_loss: 0.0460 - val_accuracy: 0.9395
# Epoch 15/15
# 7/7 [==============================] - 46s 7s/step - loss: 0.0342 - accuracy: 0.5436 - val_loss: 0.0439 - val_accuracy: 0.9436

# %%
#обучаем сеть
result = train_model.fit(xTrain, xTrain,
                   batch_size=12,
                   epochs = epochs,
                   validation_data=(xVal, xVal),
                   verbose=1,
                   callbacks=[reduce_lr, earlystopper]) # добавляем наши колбеки
# Out:
# Epoch 1/15
# 21/21 [==============================] - 47s 2s/step - loss: 0.0326 - accuracy: 0.5773 - val_loss: 0.0398 - val_accuracy: 0.9512
# Epoch 2/15
# 21/21 [==============================] - 47s 2s/step - loss: 0.0285 - accuracy: 0.6241 - val_loss: 0.0354 - val_accuracy: 0.9524
# Epoch 3/15
# 21/21 [==============================] - 47s 2s/step - loss: 0.0251 - accuracy: 0.6580 - val_loss: 0.0328 - val_accuracy: 0.9528
# Epoch 4/15
# 21/21 [==============================] - 47s 2s/step - loss: 0.0221 - accuracy: 0.6912 - val_loss: 0.0301 - val_accuracy: 0.9529
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# Epoch 5/15
# 21/21 [==============================] - 47s 2s/step - loss: 0.0205 - accuracy: 0.7071 - val_loss: 0.0292 - val_accuracy: 0.9530
# Epoch 6/15
# 21/21 [==============================] - 47s 2s/step - loss: 0.0202 - accuracy: 0.7133 - val_loss: 0.0280 - val_accuracy: 0.9530
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# Epoch 7/15
# 21/21 [==============================] - 47s 2s/step - loss: 0.0194 - accuracy: 0.7174 - val_loss: 0.0270 - val_accuracy: 0.9531
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# Epoch 8/15
# 21/21 [==============================] - 47s 2s/step - loss: 0.0191 - accuracy: 0.7194 - val_loss: 0.0260 - val_accuracy: 0.9531
# Epoch 9/15
# 21/21 [==============================] - 47s 2s/step - loss: 0.0195 - accuracy: 0.7200 - val_loss: 0.0248 - val_accuracy: 0.9530
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 10/15
# 21/21 [==============================] - 47s 2s/step - loss: 0.0195 - accuracy: 0.7210 - val_loss: 0.0232 - val_accuracy: 0.9525
# Epoch 11/15
# 21/21 [==============================] - 47s 2s/step - loss: 0.0195 - accuracy: 0.7217 - val_loss: 0.0215 - val_accuracy: 0.9512
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping

# %%
train_model.save('/content/drive/MyDrive/Colab Bases/Команда УИИ/model_AC_1.h5')
train_model.save_weights('/content/drive/MyDrive/Colab Bases/Команда УИИ/weights_model_AC_1.h5')

# %%
from tensorflow import keras

train_model = keras.models.load_model('/content/drive/MyDrive/Colab Bases/Команда УИИ/model_AC_1.h5')

# %% [markdown]
# # Проверка на MSE

# %%
# создадим функцию среднеквадратичной ошибки
def getMSEmasive(x1, x2): 
  return np.square(np.subtract(x1, x2)) # и возвращаем сумму квадратов разницы, делённую на длину разницы

# %% [markdown]
# MSE на xVal

# %%
# Возьмем среднеквадратичные ошибки и выведем их для лиц 
pred_face = train_model.predict(xVal)
MSEs = getMSEmasive(xVal, pred_face)
errors = [MSEs[i].mean() for i in range(xVal.shape[0])] # посчитаем ошибку для всех изображений
#print("Ошибка на xTrain:", errors[80:]) #посмотрим последнии 20
print("Средняя ошибка на xTrain:", np.round(np.sum(errors) / len(errors), 4)) # посчитаем для последних 20 среднюю ошибку
print("Минимальная ошибка на xTrain:", np.round(np.min(errors),4)) #найдем минимальную ошибку
# Out:
# Средняя ошибка на xTrain: 0.026
# Минимальная ошибка на xTrain: 0.0135

# %% [markdown]
# # Чужие лица

# %%
from google.colab.patches import cv2_imshow
import cv2
import time
#path_test_video = '/content/drive/MyDrive/Colab Bases/Команда УИИ/Shou_Trumana_Kinosimka.RU (online-video-cutter.com).mp4'
path_cut_vidio = '/content/drive/MyDrive/Colab Bases/Команда УИИ/cut_video.mp4'
cap = cv2.VideoCapture(path_cut_vidio)

start = time.time()
#cadrswithface = []
#old_film = []

np_cutfilm = []
all_persons = []
cadr = 0
while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    if not ret:
      break

    if cadr % 5 == 0:
      image_base = frame
      gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
      faces = face_cascade.detectMultiScale(
          gray,
          scaleFactor= 1.1,
          minNeighbors= 5,
          minSize=(10, 10)
      )
      #faces_detected = "Лиц обнаружено: " + format(len(faces))
      #print(faces_detected)
      # Рисуем квадраты вокруг лиц
      for i,(x, y, w, h) in enumerate(faces):
          cv2.rectangle(faces, (x, y), (x+w, y+h), (255, 255, 0), 2)

      #cv2_imshow(image)

      #cv2_imshow(image_base[y:y+h,x:x+w,:])
          path_save = '/content/drive/MyDrive/Colab Bases/Команда УИИ/Aliens/' + str(cadr)+'_'+str(i) + '.jpg'

          face_np = image_base[y:y+h,x:x+w,:]

          face_img = Image.fromarray(face_np) #cv2_imshow(face_np) # cv2.imwrite(face_np) #path_save)#
          face_img = face_img.resize((128, 128)) 
          face_np = np.array(face_img)
          cv2.imwrite(path_save, face_np)##
    cadr+=1
          
    cv2.waitKey(1) & 0xFF

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()

finish = time.time() - start
print('время обработки', finish)
# Out:
# время обработки 19.73922824859619

# %%
# Глобальные параметры
img_width = 128 # Ширина уменьшенной картинки 
img_height = 128 # Высота уменьшенной картинки 

directory = '/content/drive/MyDrive/Colab Bases/Команда УИИ/Aliens/' # Указываем путь к обучающей выборке с оригинальными изображения

# %%
from tensorflow.keras.preprocessing import image # Импортируем модуль image для работы с изображениями
cur_time = time.time() # Засекаем текущее время
aliens_images = []
for filename in sorted(os.listdir(directory)): # Проходим по всем файлам в каталоге по указанному пути     
    aliens_images.append(image.load_img(os.path.join(directory,filename), color_mode='rgb',
                                          target_size=(img_width, img_height))) # Читаем очередную картинку и добавляем ее в список изображения с указанным target_size           
print ('Выборка загржена. Время загрузки: ', round(time.time() - cur_time, 2), 'c', sep='') # Отображаем время загрузки картинок проверочной выборки
# Out:
# Выборка загржена. Время загрузки: 0.04c

# %%
aliens_data = []
for img in aliens_images:
    x = image.img_to_array(img) # Переводим изображение в numpy-массив размерностью: высота - ширина - количество каналов
    aliens_data.append(x) # Добавляем очередной элемент в xTrain

aliens_data = np.array(aliens_data) # Переводим в numpy
aliens_data = aliens_data / 255. # Трансофрмируем значение в диапазон от -1 до 1
aliens_data.shape
# Out:
# (27, 128, 128, 3)

# %% [markdown]
# MSE на Aliens

# %%
# Возьмем среднеквадратичные ошибки и выведем их для лиц 
pred_face = train_model.predict(aliens_data)
MSEs = getMSEmasive(aliens_data, pred_face)
errors = [MSEs[i].mean() for i in range(aliens_data.shape[0])] # посчитаем ошибку для всех изображений
#print("Ошибка на xTrain:", errors[80:]) #посмотрим последнии 20
print("Средняя ошибка на aliens_data:", np.round(np.sum(errors) / len(errors), 4)) # посчитаем для последних 20 среднюю ошибку
print("Минимальная ошибка на aliens_data:", np.round(np.min(errors),4)) #найдем минимальную ошибку
# Out:
# Средняя ошибка на aliens_data: 0.0317
# Минимальная ошибка на aliens_data: 0.01

# %%
range(xVal.shape[0])
# Out:
# range(0, 63)

# %%
idx = np.random.choice(range(xVal.shape[0]), aliens_data.shape[0])

MSEs = getMSEmasive(aliens_data, xVal[idx])
errors = [MSEs[i].mean() for i in range(aliens_data.shape[0])] # посчитаем ошибку для всех изображений
#print("Ошибка на xTrain:", errors[80:]) #посмотрим последнии 20
print("Средняя ошибка на aliens_data:", np.round(np.sum(errors) / len(errors), 4)) # посчитаем для последних 20 среднюю ошибку
print("Минимальная ошибка на aliens_data:", np.round(np.min(errors),4)) #найдем минимальную ошибку
# Out:
# Средняя ошибка на aliens_data: 0.0662
# Минимальная ошибка на aliens_data: 0.0113

# %%
idx = np.random.choice(range(xTrain.shape[0]), aliens_data.shape[0])

MSEs = getMSEmasive(aliens_data, xTrain[idx])
errors = [MSEs[i].mean() for i in range(aliens_data.shape[0])] # посчитаем ошибку для всех изображений
#print("Ошибка на xTrain:", errors[80:]) #посмотрим последнии 20
print("Средняя ошибка на aliens_data:", np.round(np.sum(errors) / len(errors), 4)) # посчитаем для последних 20 среднюю ошибку
print("Минимальная ошибка на aliens_data:", np.round(np.min(errors),4)) #найдем минимальную ошибку
# Out:
# Средняя ошибка на aliens_data: 0.0617
# Минимальная ошибка на aliens_data: 0.0154

# %%
idx = np.random.choice(range(xTrain.shape[0]), xVal.shape[0])
MSEs = getMSEmasive(xTrain[idx], xVal)
errors = [MSEs[i].mean() for i in range(aliens_data.shape[0])] # посчитаем ошибку для всех изображений
#print("Ошибка на xTrain:", errors[80:]) #посмотрим последнии 20
print("Средняя ошибка на aliens_data:", np.round(np.sum(errors) / len(errors), 4)) # посчитаем для последних 20 среднюю ошибку
print("Минимальная ошибка на aliens_data:", np.round(np.min(errors),4)) #найдем минимальную ошибку
# Out:
# Средняя ошибка на aliens_data: 0.0418
# Минимальная ошибка на aliens_data: 0.0072

# %% [markdown]
# # Проверка кода сравнеия по МСЕ

# %%
from google.colab.patches import cv2_imshow
import cv2
import time
path_test_video = '/content/drive/MyDrive/Colab Bases/Команда УИИ/Shou_Trumana_Kinosimka.RU (online-video-cutter.com).mp4'
#path_cut_vidio = '/content/drive/MyDrive/Colab Bases/Команда УИИ/cut_video.mp4'
cap = cv2.VideoCapture(path_test_video)

start = time.time()

np_cutfilm = []
set_frame = []
cadr = 0
while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()
   
    if not ret:
      break

    if cadr % 2 == 0:
      image_base = frame
      gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
      faces = face_cascade.detectMultiScale(
          gray,
          scaleFactor= 1.1,
          minNeighbors= 5,
          minSize=(10, 10)
      )
      #faces_detected = "Лиц обнаружено: " + format(len(faces))
      #print(faces_detected)
      # Рисуем квадраты вокруг лиц
      frame_faces = []
      for i,(x, y, w, h) in enumerate(faces):
          #print(i)
          cv2.rectangle(faces, (x, y), (x+w, y+h), (255, 255, 0), 2)

          face_np = image_base[y:y+h,x:x+w,:]

          face_img = Image.fromarray(face_np) #cv2_imshow(face_np) # cv2.imwrite(face_np) #path_save)#
          face_img = face_img.resize((128, 128)) 
          face_np = np.array(face_img)/255.
          frame_faces.append(face_np)
          #cv2.imwrite(path_save, face_np)##
      frame_faces = np.array(frame_faces)
      if frame_faces.shape[0] != 0:
          #print(frame_faces.shape[0])
          #pred_face = train_model.predict(frame_faces)
          #MSEs = getMSEmasive(frame_faces, pred_face)
          #errors = [MSEs[i].mean() for i in range(frame_faces.shape[0])] # посчитаем ошибку для всех изображений
          idx = np.random.choice(range(xTrain.shape[0]), frame_faces.shape[0])
          MSEs = getMSEmasive(frame_faces, xTrain[idx])
          errors = [MSEs[i].mean() for i in range(frame_faces.shape[0])] # посчитаем ошибку для всех изображений
          print("Средняя ошибка на aliens_data:", np.round(np.sum(errors) / len(errors), 4)) # посчитаем для последних 20 среднюю ошибку
          print("Минимальная ошибка на aliens_data:", np.round(np.min(errors),4)) #найдем минимальную ошибку
          #print("Ошибка на xTrain:", errors[80:]) #посмотрим последнии 20
          if np.min(errors) < 0.07:
            set_frame.append(cadr)
            np_cutfilm.append(image_base)
#print("Средняя ошибка на aliens_data:", np.round(np.sum(errors) / len(errors), 4)) # посчитаем для последних 20 среднюю ошибку
#print("Минимальная ошибка на aliens_data:", np.round(np.min(errors),4)) #найдем минимальную ошибку


    cadr+=1
          
    cv2.waitKey(1) & 0xFF
set_frame = np.array(set_frame)  
np_cutfilm = np.array(np_cutfilm)
# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
print('кадров с лицами', np_cutfilm.shape)


fps_of_video = int(cv2.VideoCapture(path_cut_vidio).get(cv2.CAP_PROP_FPS))
time_persons = np_cutfilm.shape[0]/fps_of_video
time_persons = round(time_persons/60,1)
print('время людей на видео: ',time_persons, ' минут')

finish = time.time() - start
print('время обработки', finish)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Минимальная ошибка на aliens_data: 0.0197
# Средняя ошибка на aliens_data: 0.0657
# Минимальная ошибка на aliens_data: 0.0196
# Средняя ошибка на aliens_data: 0.074
# Минимальная ошибка на aliens_data: 0.0457
# Средняя ошибка на aliens_data: 0.0259
# Минимальная ошибка на aliens_data: 0.0242
# Средняя ошибка на aliens_data: 0.0285
# Минимальная ошибка на aliens_data: 0.0273
# Средняя ошибка на aliens_data: 0.0518
# Минимальная ошибка на aliens_data: 0.0216
# Средняя ошибка на aliens_data: 0.0322
# Минимальная ошибка на aliens_data: 0.0178
# Средняя ошибка на aliens_data: 0.0636
# Минимальная ошибка на aliens_data: 0.0427
# Средняя ошибка на aliens_data: 0.0449
# Минимальная ошибка на aliens_data: 0.0382
# Средняя ошибка на aliens_data: 0.0347
# Минимальная ошибка на aliens_data: 0.0202
# Средняя ошибка на aliens_data: 0.0306
# Минимальная ошибка на aliens_data: 0.0221
# Средняя ошибка на aliens_data: 0.0387
# Минимальная ошибка на aliens_data: 0.0226
# Средняя ошибка на aliens_data: 0.0641
# Минимальная ошибка на aliens_data: 0.0495
# Средняя ошибка на aliens_data: 0.0727
# Минимальная ошибка на aliens_data: 0.0614
# Средняя ошибка на aliens_data: 0.0764
# Минимальная ошибка на aliens_data: 0.0764
# Средняя ошибка на aliens_data: 0.2388
# Минимальная ошибка на aliens_data: 0.2388
# Средняя ошибка на aliens_data: 0.0446
# Минимальная ошибка на aliens_data: 0.0419
# Средняя ошибка на aliens_data: 0.0097
# Минимальная ошибка на aliens_data: 0.0097
# Средняя ошибка на aliens_data: 0.0161
# Минимальная ошибка на aliens_data: 0.0161
# Средняя ошибка на aliens_data: 0.0322
# Минимальная ошибка на aliens_data: 0.0322
# Средняя ошибка на aliens_data: 0.0226
# Минимальная ошибка на aliens_data: 0.0226
# Средняя ошибка на aliens_data: 0.019
# Минимальная ошибка на aliens_data: 0.0134
# Средняя ошибка на aliens_data: 0.0409
# Минимальная ошибка на aliens_data: 0.0296
# Средняя ошибка на aliens_data: 0.0712
# Минимальная ошибка на aliens_data: 0.0712
# Средняя ошибка на aliens_data: 0.0216
# Минимальная ошибка на aliens_data: 0.0216
# Средняя ошибка на aliens_data: 0.0466
# Минимальная ошибка на aliens_data: 0.0466
# Средняя ошибка на aliens_data: 0.0249
# Минимальная ошибка на aliens_data: 0.0249
# Средняя ошибка на aliens_data: 0.0208
# Минимальная ошибка на aliens_data: 0.0208
# Средняя ошибка на aliens_data: 0.0283
# Минимальная ошибка на aliens_data: 0.0247
# Средняя ошибка на aliens_data: 0.0418
# Минимальная ошибка на aliens_data: 0.0418
# Средняя ошибка на aliens_data: 0.0249
# Минимальная ошибка на aliens_data: 0.0249
# Средняя ошибка на aliens_data: 0.0236
# Минимальная ошибка на aliens_data: 0.0236
# Средняя ошибка на aliens_data: 0.0082
# Минимальная ошибка на aliens_data: 0.0082
# Средняя ошибка на aliens_data: 0.0453
# Минимальная ошибка на aliens_data: 0.0453
# Средняя ошибка на aliens_data: 0.0408
# Минимальная ошибка на aliens_data: 0.0408
# Средняя ошибка на aliens_data: 0.0437
# Минимальная ошибка на aliens_data: 0.0437
# Средняя ошибка на aliens_data: 0.1244
# Минимальная ошибка на aliens_data: 0.1244
# Средняя ошибка на aliens_data: 0.0507
# Минимальная ошибка на aliens_data: 0.0507
# Средняя ошибка на aliens_data: 0.0252
# Минимальная ошибка на aliens_data: 0.0252
# Средняя ошибка на aliens_data: 0.0249
# Минимальная ошибка на aliens_data: 0.0249
# Средняя ошибка на aliens_data: 0.0577
# Минимальная ошибка на aliens_data: 0.0577
# Средняя ошибка на aliens_data: 0.0307
# Минимальная ошибка на aliens_data: 0.0307
# Средняя ошибка на aliens_data: 0.1304
# Минимальная ошибка на aliens_data: 0.1304
# Средняя ошибка на aliens_data: 0.0275
# Минимальная ошибка на aliens_data: 0.0275
# Средняя ошибка на aliens_data: 0.0551
# Минимальная ошибка на aliens_data: 0.0551
# Средняя ошибка на aliens_data: 0.0268
# Минимальная ошибка на aliens_data: 0.0268
# Средняя ошибка на aliens_data: 0.0438
# Минимальная ошибка на aliens_data: 0.039
# Средняя ошибка на aliens_data: 0.0449
# Минимальная ошибка на aliens_data: 0.0379
# Средняя ошибка на aliens_data: 0.0515
# Минимальная ошибка на aliens_data: 0.0515
# Средняя ошибка на aliens_data: 0.048
# Минимальная ошибка на aliens_data: 0.048
# Средняя ошибка на aliens_data: 0.0579
# Минимальная ошибка на aliens_data: 0.0579
# Средняя ошибка на aliens_data: 0.0967
# Минимальная ошибка на aliens_data: 0.077
# Средняя ошибка на aliens_data: 0.0486
# Минимальная ошибка на aliens_data: 0.0396
# Средняя ошибка на aliens_data: 0.1007
# Минимальная ошибка на aliens_data: 0.0946
# Средняя ошибка на aliens_data: 0.0212
# Минимальная ошибка на aliens_data: 0.0212
# Средняя ошибка на aliens_data: 0.1164
# Минимальная ошибка на aliens_data: 0.1164
# Средняя ошибка на aliens_data: 0.0403
# Минимальная ошибка на aliens_data: 0.0403
# Средняя ошибка на aliens_data: 0.0497
# Минимальная ошибка на aliens_data: 0.0497
# Средняя ошибка на aliens_data: 0.0445
# Минимальная ошибка на aliens_data: 0.0445
# Средняя ошибка на aliens_data: 0.1104
# Минимальная ошибка на aliens_data: 0.1104
# Средняя ошибка на aliens_data: 0.0842
# Минимальная ошибка на aliens_data: 0.0842
# Средняя ошибка на aliens_data: 0.11
# Минимальная ошибка на aliens_data: 0.11
# Средняя ошибка на aliens_data: 0.101
# Минимальная ошибка на aliens_data: 0.101
# Средняя ошибка на aliens_data: 0.1057
# Минимальная ошибка на aliens_data: 0.1057
# Средняя ошибка на aliens_data: 0.0303
# Минимальная ошибка на aliens_data: 0.0303
# Средняя ошибка на aliens_data: 0.0738
# Минимальная ошибка на aliens_data: 0.0738
# Средняя ошибка на aliens_data: 0.0476
# Минимальная ошибка на aliens_data: 0.0476
# Средняя ошибка на aliens_data: 0.0273
# Минимальная ошибка на aliens_data: 0.0273
# Средняя ошибка на aliens_data: 0.0357
# Минимальная ошибка на aliens_data: 0.0357
# Средняя ошибка на aliens_data: 0.1207
# Минимальная ошибка на aliens_data: 0.1207
# Средняя ошибка на aliens_data: 0.0664
# Минимальная ошибка на aliens_data: 0.0228
# Средняя ошибка на aliens_data: 0.0354
# Минимальная ошибка на aliens_data: 0.0354
# Средняя ошибка на aliens_data: 0.0718
# Минимальная ошибка на aliens_data: 0.0718
# Средняя ошибка на aliens_data: 0.0385
# Минимальная ошибка на aliens_data: 0.0283
# Средняя ошибка на aliens_data: 0.0867
# Минимальная ошибка на aliens_data: 0.0867
# Средняя ошибка на aliens_data: 0.0463
# Минимальная ошибка на aliens_data: 0.0463
# Средняя ошибка на aliens_data: 0.0442
# Минимальная ошибка на aliens_data: 0.0442
# Средняя ошибка на aliens_data: 0.0698
# Минимальная ошибка на aliens_data: 0.0482
# Средняя ошибка на aliens_data: 0.0751
# Минимальная ошибка на aliens_data: 0.0674
# Средняя ошибка на aliens_data: 0.0407
# Минимальная ошибка на aliens_data: 0.033
# Средняя ошибка на aliens_data: 0.0304
# Минимальная ошибка на aliens_data: 0.0257
# Средняя ошибка на aliens_data: 0.0651
# Минимальная ошибка на aliens_data: 0.0446
# Средняя ошибка на aliens_data: 0.0378
# Минимальная ошибка на aliens_data: 0.0263
# Средняя ошибка на aliens_data: 0.0987
# Минимальная ошибка на aliens_data: 0.0987
# Средняя ошибка на aliens_data: 0.0389
# Минимальная ошибка на aliens_data: 0.0389
# Средняя ошибка на aliens_data: 0.0758
# Минимальная ошибка на aliens_data: 0.033
# Средняя ошибка на aliens_data: 0.0346
# Минимальная ошибка на aliens_data: 0.0346
# Средняя ошибка на aliens_data: 0.052
# Минимальная ошибка на aliens_data: 0.052
# Средняя ошибка на aliens_data: 0.0202
# Минимальная ошибка на aliens_data: 0.0202
# Средняя ошибка на aliens_data: 0.0325
# Минимальная ошибка на aliens_data: 0.0325
# Средняя ошибка на aliens_data: 0.1143
# Минимальная ошибка на aliens_data: 0.1143
# Средняя ошибка на aliens_data: 0.0205
# Минимальная ошибка на aliens_data: 0.0205
# Средняя ошибка на aliens_data: 0.0156
# Минимальная ошибка на aliens_data: 0.0156
# Средняя ошибка на aliens_data: 0.0339
# Минимальная ошибка на aliens_data: 0.0201
# Средняя ошибка на aliens_data: 0.0689
# Минимальная ошибка на aliens_data: 0.0689
# Средняя ошибка на aliens_data: 0.0405
# Минимальная ошибка на aliens_data: 0.0228
# Средняя ошибка на aliens_data: 0.0092
# Минимальная ошибка на aliens_data: 0.0092
# Средняя ошибка на aliens_data: 0.078
# Минимальная ошибка на aliens_data: 0.0269
# Средняя ошибка на aliens_data: 0.0402
# Минимальная ошибка на aliens_data: 0.0238
# Средняя ошибка на aliens_data: 0.0351
# Минимальная ошибка на aliens_data: 0.0287
# Средняя ошибка на aliens_data: 0.0402
# Минимальная ошибка на aliens_data: 0.0344
# Средняя ошибка на aliens_data: 0.0833
# Минимальная ошибка на aliens_data: 0.0631
# Средняя ошибка на aliens_data: 0.0677
# Минимальная ошибка на aliens_data: 0.055
# Средняя ошибка на aliens_data: 0.0513
# Минимальная ошибка на aliens_data: 0.0414
# Средняя ошибка на aliens_data: 0.0426
# Минимальная ошибка на aliens_data: 0.0426
# Средняя ошибка на aliens_data: 0.035
# Минимальная ошибка на aliens_data: 0.035
# Средняя ошибка на aliens_data: 0.0453
# Минимальная ошибка на aliens_data: 0.0453
# Средняя ошибка на aliens_data: 0.0418
# Минимальная ошибка на aliens_data: 0.0418
# Средняя ошибка на aliens_data: 0.045
# Минимальная ошибка на aliens_data: 0.045
# Средняя ошибка на aliens_data: 0.0563
# Минимальная ошибка на aliens_data: 0.0424
# Средняя ошибка на aliens_data: 0.1459
# Минимальная ошибка на aliens_data: 0.101
# Средняя ошибка на aliens_data: 0.0276
# Минимальная ошибка на aliens_data: 0.0225
# Средняя ошибка на aliens_data: 0.0395
# Минимальная ошибка на aliens_data: 0.0154
# Средняя ошибка на aliens_data: 0.0238
# Минимальная ошибка на aliens_data: 0.0216
# Средняя ошибка на aliens_data: 0.1195
# Минимальная ошибка на aliens_data: 0.0588
# Средняя ошибка на aliens_data: 0.0499
# Минимальная ошибка на aliens_data: 0.0371
# Средняя ошибка на aliens_data: 0.142
# Минимальная ошибка на aliens_data: 0.0959
# Средняя ошибка на aliens_data: 0.0314
# Минимальная ошибка на aliens_data: 0.0314
# Средняя ошибка на aliens_data: 0.0235
# Минимальная ошибка на aliens_data: 0.0235
# Средняя ошибка на aliens_data: 0.1225
# Минимальная ошибка на aliens_data: 0.1225
# Средняя ошибка на aliens_data: 0.0548
# Минимальная ошибка на aliens_data: 0.0548
# Средняя ошибка на aliens_data: 0.1674
# Минимальная ошибка на aliens_data: 0.1674
# Средняя ошибка на aliens_data: 0.0386
# Минимальная ошибка на aliens_data: 0.0386
# Средняя ошибка на aliens_data: 0.0721
# Минимальная ошибка на aliens_data: 0.0721
# Средняя ошибка на aliens_data: 0.0329
# Минимальная ошибка на aliens_data: 0.0329
# Средняя ошибка на aliens_data: 0.0475
# Минимальная ошибка на aliens_data: 0.0475
# Средняя ошибка на aliens_data: 0.0504
# Минимальная ошибка на aliens_data: 0.0504
# Средняя ошибка на aliens_data: 0.0649
# Минимальная ошибка на aliens_data: 0.0649
# Средняя ошибка на aliens_data: 0.1013
# Минимальная ошибка на aliens_data: 0.1013
# Средняя ошибка на aliens_data: 0.0361
# Минимальная ошибка на aliens_data: 0.0153
# Средняя ошибка на aliens_data: 0.057
# Минимальная ошибка на aliens_data: 0.057
# Средняя ошибка на aliens_data: 0.0374
# Минимальная ошибка на aliens_data: 0.0374
# Средняя ошибка на aliens_data: 0.0516
# Минимальная ошибка на aliens_data: 0.0516
# Средняя ошибка на aliens_data: 0.0674
# Минимальная ошибка на aliens_data: 0.0674
# Средняя ошибка на aliens_data: 0.1105
# Минимальная ошибка на aliens_data: 0.1105
# Средняя ошибка на aliens_data: 0.0667
# Минимальная ошибка на aliens_data: 0.0261
# Средняя ошибка на aliens_data: 0.1017
# Минимальная ошибка на aliens_data: 0.1017
# Средняя ошибка на aliens_data: 0.0352
# Минимальная ошибка на aliens_data: 0.0352
# Средняя ошибка на aliens_data: 0.044
# Минимальная ошибка на aliens_data: 0.044
# Средняя ошибка на aliens_data: 0.0457
# Минимальная ошибка на aliens_data: 0.0457
# Средняя ошибка на aliens_data: 0.0546
# Минимальная ошибка на aliens_data: 0.0546
# Средняя ошибка на aliens_data: 0.0937
# Минимальная ошибка на aliens_data: 0.0937
# Средняя ошибка на aliens_data: 0.0375
# Минимальная ошибка на aliens_data: 0.0375
# Средняя ошибка на aliens_data: 0.1126
# Минимальная ошибка на aliens_data: 0.1126
# Средняя ошибка на aliens_data: 0.052
# Минимальная ошибка на aliens_data: 0.052
# Средняя ошибка на aliens_data: 0.0349
# Минимальная ошибка на aliens_data: 0.0349
# Средняя ошибка на aliens_data: 0.1227
# Минимальная ошибка на aliens_data: 0.1227
# Средняя ошибка на aliens_data: 0.0346
# Минимальная ошибка на aliens_data: 0.0346
# Средняя ошибка на aliens_data: 0.034
# Минимальная ошибка на aliens_data: 0.034
# Средняя ошибка на aliens_data: 0.0597
# Минимальная ошибка на aliens_data: 0.0597
# Средняя ошибка на aliens_data: 0.0091
# Минимальная ошибка на aliens_data: 0.0091
# Средняя ошибка на aliens_data: 0.1349
# Минимальная ошибка на aliens_data: 0.1349
# Средняя ошибка на aliens_data: 0.05
# Минимальная ошибка на aliens_data: 0.05
# Средняя ошибка на aliens_data: 0.0385
# Минимальная ошибка на aliens_data: 0.0385
# Средняя ошибка на aliens_data: 0.032
# Минимальная ошибка на aliens_data: 0.032
# Средняя ошибка на aliens_data: 0.0452
# Минимальная ошибка на aliens_data: 0.0452
# Средняя ошибка на aliens_data: 0.1765
# Минимальная ошибка на aliens_data: 0.1765
# Средняя ошибка на aliens_data: 0.0416
# Минимальная ошибка на aliens_data: 0.0416
# Средняя ошибка на aliens_data: 0.0396
# Минимальная ошибка на aliens_data: 0.0396
# Средняя ошибка на aliens_data: 0.0613
# Минимальная ошибка на aliens_data: 0.0613
# Средняя ошибка на aliens_data: 0.1109
# Минимальная ошибка на aliens_data: 0.1109
# Средняя ошибка на aliens_data: 0.0974
# Минимальная ошибка на aliens_data: 0.0974
# Средняя ошибка на aliens_data: 0.0539
# Минимальная ошибка на aliens_data: 0.0539
# Средняя ошибка на aliens_data: 0.0721
# Минимальная ошибка на aliens_data: 0.0583
# Средняя ошибка на aliens_data: 0.0377
# Минимальная ошибка на aliens_data: 0.0308
# Средняя ошибка на aliens_data: 0.0391
# Минимальная ошибка на aliens_data: 0.0386
# Средняя ошибка на aliens_data: 0.0472
# Минимальная ошибка на aliens_data: 0.0322
# Средняя ошибка на aliens_data: 0.029
# Минимальная ошибка на aliens_data: 0.0261
# Средняя ошибка на aliens_data: 0.053
# Минимальная ошибка на aliens_data: 0.0282
# Средняя ошибка на aliens_data: 0.0555
# Минимальная ошибка на aliens_data: 0.0415
# Средняя ошибка на aliens_data: 0.0884
# Минимальная ошибка на aliens_data: 0.0884
# Средняя ошибка на aliens_data: 0.0604
# Минимальная ошибка на aliens_data: 0.0604
# Средняя ошибка на aliens_data: 0.0243
# Минимальная ошибка на aliens_data: 0.0243
# Средняя ошибка на aliens_data: 0.0593
# Минимальная ошибка на aliens_data: 0.0361
# Средняя ошибка на aliens_data: 0.0496
# Минимальная ошибка на aliens_data: 0.0485
# Средняя ошибка на aliens_data: 0.0584
# Минимальная ошибка на aliens_data: 0.0362
# Средняя ошибка на aliens_data: 0.0747
# Минимальная ошибка на aliens_data: 0.0558
# Средняя ошибка на aliens_data: 0.0382
# Минимальная ошибка на aliens_data: 0.0255
# Средняя ошибка на aliens_data: 0.051
# Минимальная ошибка на aliens_data: 0.043
# Средняя ошибка на aliens_data: 0.023
# Минимальная ошибка на aliens_data: 0.0171
# Средняя ошибка на aliens_data: 0.0869
# Минимальная ошибка на aliens_data: 0.0455
# Средняя ошибка на aliens_data: 0.0314
# Минимальная ошибка на aliens_data: 0.028
# Средняя ошибка на aliens_data: 0.0715
# Минимальная ошибка на aliens_data: 0.0256
# Средняя ошибка на aliens_data: 0.07
# Минимальная ошибка на aliens_data: 0.0354
# Средняя ошибка на aliens_data: 0.0457
# Минимальная ошибка на aliens_data: 0.0457
# Средняя ошибка на aliens_data: 0.0458
# Минимальная ошибка на aliens_data: 0.0309
# Средняя ошибка на aliens_data: 0.0336
# Минимальная ошибка на aliens_data: 0.0331
# Средняя ошибка на aliens_data: 0.0373
# Минимальная ошибка на aliens_data: 0.0373
# Средняя ошибка на aliens_data: 0.0494
# Минимальная ошибка на aliens_data: 0.0494
# Средняя ошибка на aliens_data: 0.0191
# Минимальная ошибка на aliens_data: 0.0191
# Средняя ошибка на aliens_data: 0.0443
# Минимальная ошибка на aliens_data: 0.0419
# Средняя ошибка на aliens_data: 0.0475
# Минимальная ошибка на aliens_data: 0.0438
# Средняя ошибка на aliens_data: 0.0421
# Минимальная ошибка на aliens_data: 0.0421
# Средняя ошибка на aliens_data: 0.0282
# Минимальная ошибка на aliens_data: 0.0282
# Средняя ошибка на aliens_data: 0.0436
# Минимальная ошибка на aliens_data: 0.0322
# Средняя ошибка на aliens_data: 0.0712
# Минимальная ошибка на aliens_data: 0.0452
# Средняя ошибка на aliens_data: 0.0471
# Минимальная ошибка на aliens_data: 0.0374
# Средняя ошибка на aliens_data: 0.0756
# Минимальная ошибка на aliens_data: 0.0628
# Средняя ошибка на aliens_data: 0.0406
# Минимальная ошибка на aliens_data: 0.0394
# Средняя ошибка на aliens_data: 0.0942
# Минимальная ошибка на aliens_data: 0.0803
# Средняя ошибка на aliens_data: 0.0514
# Минимальная ошибка на aliens_data: 0.0247
# Средняя ошибка на aliens_data: 0.0708
# Минимальная ошибка на aliens_data: 0.0409
# Средняя ошибка на aliens_data: 0.0245
# Минимальная ошибка на aliens_data: 0.0245
# Средняя ошибка на aliens_data: 0.0384
# Минимальная ошибка на aliens_data: 0.0384
# Средняя ошибка на aliens_data: 0.0584
# Минимальная ошибка на aliens_data: 0.0193
# Средняя ошибка на aliens_data: 0.0704
# Минимальная ошибка на aliens_data: 0.0463
# Средняя ошибка на aliens_data: 0.0627
# Минимальная ошибка на aliens_data: 0.0265
# Средняя ошибка на aliens_data: 0.0504
# Минимальная ошибка на aliens_data: 0.0443
# Средняя ошибка на aliens_data: 0.0432
# Минимальная ошибка на aliens_data: 0.0214
# Средняя ошибка на aliens_data: 0.054
# Минимальная ошибка на aliens_data: 0.054
# Средняя ошибка на aliens_data: 0.0377
# Минимальная ошибка на aliens_data: 0.0309
# Средняя ошибка на aliens_data: 0.041
# Минимальная ошибка на aliens_data: 0.0272
# Средняя ошибка на aliens_data: 0.0354
# Минимальная ошибка на aliens_data: 0.0241
# Средняя ошибка на aliens_data: 0.0561
# Минимальная ошибка на aliens_data: 0.0434
# Средняя ошибка на aliens_data: 0.0602
# Минимальная ошибка на aliens_data: 0.042
# Средняя ошибка на aliens_data: 0.0602
# Минимальная ошибка на aliens_data: 0.0361
# Средняя ошибка на aliens_data: 0.041
# Минимальная ошибка на aliens_data: 0.0379
# Средняя ошибка на aliens_data: 0.0403
# Минимальная ошибка на aliens_data: 0.0403
# Средняя ошибка на aliens_data: 0.0673
# Минимальная ошибка на aliens_data: 0.0664
# Средняя ошибка на aliens_data: 0.0493
# Минимальная ошибка на aliens_data: 0.0374
# Средняя ошибка на aliens_data: 0.0544
# Минимальная ошибка на aliens_data: 0.0319
# Средняя ошибка на aliens_data: 0.0504
# Минимальная ошибка на aliens_data: 0.0338
# Средняя ошибка на aliens_data: 0.0349
# Минимальная ошибка на aliens_data: 0.023
# Средняя ошибка на aliens_data: 0.0461
# Минимальная ошибка на aliens_data: 0.0385
# Средняя ошибка на aliens_data: 0.0634
# Минимальная ошибка на aliens_data: 0.0419
# Средняя ошибка на aliens_data: 0.0489
# Минимальная ошибка на aliens_data: 0.0308
# Средняя ошибка на aliens_data: 0.0451
# Минимальная ошибка на aliens_data: 0.0451
# Средняя ошибка на aliens_data: 0.0834
# Минимальная ошибка на aliens_data: 0.0834
# Средняя ошибка на aliens_data: 0.0315
# Минимальная ошибка на aliens_data: 0.0269
# Средняя ошибка на aliens_data: 0.0304
# Минимальная ошибка на aliens_data: 0.0304
# Средняя ошибка на aliens_data: 0.0545
# Минимальная ошибка на aliens_data: 0.0323
# Средняя ошибка на aliens_data: 0.0241
# Минимальная ошибка на aliens_data: 0.0241
# Средняя ошибка на aliens_data: 0.0317
# Минимальная ошибка на aliens_data: 0.0317
# Средняя ошибка на aliens_data: 0.0278
# Минимальная ошибка на aliens_data: 0.0278
# Средняя ошибка на aliens_data: 0.0611
# Минимальная ошибка на aliens_data: 0.0215
# Средняя ошибка на aliens_data: 0.027
# Минимальная ошибка на aliens_data: 0.027
# Средняя ошибка на aliens_data: 0.026
# Минимальная ошибка на aliens_data: 0.026
# Средняя ошибка на aliens_data: 0.0653
# Минимальная ошибка на aliens_data: 0.0354
# Средняя ошибка на aliens_data: 0.0308
# Минимальная ошибка на aliens_data: 0.0308
# Средняя ошибка на aliens_data: 0.06
# Минимальная ошибка на aliens_data: 0.0282
# Средняя ошибка на aliens_data: 0.0561
# Минимальная ошибка на aliens_data: 0.0251
# Средняя ошибка на aliens_data: 0.1013
# Минимальная ошибка на aliens_data: 0.0126
# Средняя ошибка на aliens_data: 0.041
# Минимальная ошибка на aliens_data: 0.0258
# Средняя ошибка на aliens_data: 0.0282
# Минимальная ошибка на aliens_data: 0.0188
# Средняя ошибка на aliens_data: 0.065
# Минимальная ошибка на aliens_data: 0.0321
# Средняя ошибка на aliens_data: 0.0257
# Минимальная ошибка на aliens_data: 0.023
# Средняя ошибка на aliens_data: 0.0292
# Минимальная ошибка на aliens_data: 0.0292
# Средняя ошибка на aliens_data: 0.0187
# Минимальная ошибка на aliens_data: 0.0187
# Средняя ошибка на aliens_data: 0.0356
# Минимальная ошибка на aliens_data: 0.0356
# Средняя ошибка на aliens_data: 0.0379
# Минимальная ошибка на aliens_data: 0.0379
# Средняя ошибка на aliens_data: 0.0357
# Минимальная ошибка на aliens_data: 0.0357
# Средняя ошибка на aliens_data: 0.0333
# Минимальная ошибка на aliens_data: 0.0333
# Средняя ошибка на aliens_data: 0.0888
# Минимальная ошибка на aliens_data: 0.0888
# Средняя ошибка на aliens_data: 0.0296
# Минимальная ошибка на aliens_data: 0.0296
# Средняя ошибка на aliens_data: 0.0273
# Минимальная ошибка на aliens_data: 0.0273
# Средняя ошибка на aliens_data: 0.0236
# Минимальная ошибка на aliens_data: 0.0236
# Средняя ошибка на aliens_data: 0.0799
# Минимальная ошибка на aliens_data: 0.0799
# Средняя ошибка на aliens_data: 0.0397
# Минимальная ошибка на aliens_data: 0.0397
# Средняя ошибка на aliens_data: 0.0429
# Минимальная ошибка на aliens_data: 0.0429
# Средняя ошибка на aliens_data: 0.024
# Минимальная ошибка на aliens_data: 0.024
# Средняя ошибка на aliens_data: 0.0973
# Минимальная ошибка на aliens_data: 0.0973
# Средняя ошибка на aliens_data: 0.0535
# Минимальная ошибка на aliens_data: 0.0535
# Средняя ошибка на aliens_data: 0.0305
# Минимальная ошибка на aliens_data: 0.0305
# Средняя ошибка на aliens_data: 0.1025
# Минимальная ошибка на aliens_data: 0.035
# Средняя ошибка на aliens_data: 0.0389
# Минимальная ошибка на aliens_data: 0.0389
# Средняя ошибка на aliens_data: 0.0301
# Минимальная ошибка на aliens_data: 0.0301
# Средняя ошибка на aliens_data: 0.0345
# Минимальная ошибка на aliens_data: 0.0345
# Средняя ошибка на aliens_data: 0.0323
# Минимальная ошибка на aliens_data: 0.0323
# Средняя ошибка на aliens_data: 0.0764
# Минимальная ошибка на aliens_data: 0.0764
# Средняя ошибка на aliens_data: 0.0746
# Минимальная ошибка на aliens_data: 0.0746
# Средняя ошибка на aliens_data: 0.0802
# Минимальная ошибка на aliens_data: 0.0802
# Средняя ошибка на aliens_data: 0.033
# Минимальная ошибка на aliens_data: 0.033
# Средняя ошибка на aliens_data: 0.0497
# Минимальная ошибка на aliens_data: 0.0239
# Средняя ошибка на aliens_data: 0.0313
# Минимальная ошибка на aliens_data: 0.0313
# Средняя ошибка на aliens_data: 0.0314
# Минимальная ошибка на aliens_data: 0.0314
# Средняя ошибка на aliens_data: 0.0461
# Минимальная ошибка на aliens_data: 0.0461
# Средняя ошибка на aliens_data: 0.0986
# Минимальная ошибка на aliens_data: 0.0986
# Средняя ошибка на aliens_data: 0.0929
# Минимальная ошибка на aliens_data: 0.0929
# Средняя ошибка на aliens_data: 0.0768
# Минимальная ошибка на aliens_data: 0.0768
# Средняя ошибка на aliens_data: 0.0724
# Минимальная ошибка на aliens_data: 0.0724
# Средняя ошибка на aliens_data: 0.1014
# Минимальная ошибка на aliens_data: 0.1014
# Средняя ошибка на aliens_data: 0.031
# Минимальная ошибка на aliens_data: 0.031
# Средняя ошибка на aliens_data: 0.0516
# Минимальная ошибка на aliens_data: 0.0516
# Средняя ошибка на aliens_data: 0.0384
# Минимальная ошибка на aliens_data: 0.0384
# Средняя ошибка на aliens_data: 0.0978
# Минимальная ошибка на aliens_data: 0.0978
# Средняя ошибка на aliens_data: 0.0406
# Минимальная ошибка на aliens_data: 0.0406
# Средняя ошибка на aliens_data: 0.0565
# Минимальная ошибка на aliens_data: 0.0565
# Средняя ошибка на aliens_data: 0.0353
# Минимальная ошибка на aliens_data: 0.0353
# Средняя ошибка на aliens_data: 0.0362
# Минимальная ошибка на aliens_data: 0.0362
# Средняя ошибка на aliens_data: 0.039
# Минимальная ошибка на aliens_data: 0.039
# Средняя ошибка на aliens_data: 0.0539
# Минимальная ошибка на aliens_data: 0.0539
# Средняя ошибка на aliens_data: 0.0441
# Минимальная ошибка на aliens_data: 0.0441
# Средняя ошибка на aliens_data: 0.0377
# Минимальная ошибка на aliens_data: 0.0377
# Средняя ошибка на aliens_data: 0.0489
# Минимальная ошибка на aliens_data: 0.0489
# Средняя ошибка на aliens_data: 0.0821
# Минимальная ошибка на aliens_data: 0.0821
# Средняя ошибка на aliens_data: 0.0248
# Минимальная ошибка на aliens_data: 0.0248
# Средняя ошибка на aliens_data: 0.028
# Минимальная ошибка на aliens_data: 0.028
# Средняя ошибка на aliens_data: 0.0426
# Минимальная ошибка на aliens_data: 0.0426
# Средняя ошибка на aliens_data: 0.0196
# Минимальная ошибка на aliens_data: 0.0196
# Средняя ошибка на aliens_data: 0.0702
# Минимальная ошибка на aliens_data: 0.0702
# Средняя ошибка на aliens_data: 0.0315
# Минимальная ошибка на aliens_data: 0.0315
# Средняя ошибка на aliens_data: 0.0452
# Минимальная ошибка на aliens_data: 0.0452
# Средняя ошибка на aliens_data: 0.0473
# Минимальная ошибка на aliens_data: 0.0473
# Средняя ошибка на aliens_data: 0.0829
# Минимальная ошибка на aliens_data: 0.0829
# Средняя ошибка на aliens_data: 0.0749
# Минимальная ошибка на aliens_data: 0.0749
# Средняя ошибка на aliens_data: 0.0311
# Минимальная ошибка на aliens_data: 0.0311
# Средняя ошибка на aliens_data: 0.0365
# Минимальная ошибка на aliens_data: 0.0365
# Средняя ошибка на aliens_data: 0.1282
# Минимальная ошибка на aliens_data: 0.1282
# Средняя ошибка на aliens_data: 0.0352
# Минимальная ошибка на aliens_data: 0.0352
# Средняя ошибка на aliens_data: 0.0341
# Минимальная ошибка на aliens_data: 0.0341
# Средняя ошибка на aliens_data: 0.0492
# Минимальная ошибка на aliens_data: 0.0492
# Средняя ошибка на aliens_data: 0.0312
# Минимальная ошибка на aliens_data: 0.0312
# Средняя ошибка на aliens_data: 0.0553
# Минимальная ошибка на aliens_data: 0.0553
# Средняя ошибка на aliens_data: 0.0525
# Минимальная ошибка на aliens_data: 0.0489
# Средняя ошибка на aliens_data: 0.0418
# Минимальная ошибка на aliens_data: 0.0418
# Средняя ошибка на aliens_data: 0.0182
# Минимальная ошибка на aliens_data: 0.0182
# Средняя ошибка на aliens_data: 0.0131
# Минимальная ошибка на aliens_data: 0.0131
# Средняя ошибка на aliens_data: 0.0279
# Минимальная ошибка на aliens_data: 0.0279
# Средняя ошибка на aliens_data: 0.0194
# Минимальная ошибка на aliens_data: 0.0194
# Средняя ошибка на aliens_data: 0.1226
# Минимальная ошибка на aliens_data: 0.1226
# Средняя ошибка на aliens_data: 0.0444
# Минимальная ошибка на aliens_data: 0.0444
# Средняя ошибка на aliens_data: 0.0832
# Минимальная ошибка на aliens_data: 0.0832
# Средняя ошибка на aliens_data: 0.0471
# Минимальная ошибка на aliens_data: 0.0471
# Средняя ошибка на aliens_data: 0.0899
# Минимальная ошибка на aliens_data: 0.0899
# Средняя ошибка на aliens_data: 0.0332
# Минимальная ошибка на aliens_data: 0.0332
# Средняя ошибка на aliens_data: 0.0235
# Минимальная ошибка на aliens_data: 0.0235
# Средняя ошибка на aliens_data: 0.1021
# Минимальная ошибка на aliens_data: 0.1021
# Средняя ошибка на aliens_data: 0.1039
# Минимальная ошибка на aliens_data: 0.1039
# Средняя ошибка на aliens_data: 0.0502
# Минимальная ошибка на aliens_data: 0.0502
# Средняя ошибка на aliens_data: 0.1435
# Минимальная ошибка на aliens_data: 0.1435
# Средняя ошибка на aliens_data: 0.0378
# Минимальная ошибка на aliens_data: 0.0378
# Средняя ошибка на aliens_data: 0.0467
# Минимальная ошибка на aliens_data: 0.0422
# Средняя ошибка на aliens_data: 0.0273
# Минимальная ошибка на aliens_data: 0.0273
# Средняя ошибка на aliens_data: 0.0599
# Минимальная ошибка на aliens_data: 0.0599
# Средняя ошибка на aliens_data: 0.0317
# Минимальная ошибка на aliens_data: 0.0215
# Средняя ошибка на aliens_data: 0.0246
# Минимальная ошибка на aliens_data: 0.0226
# Средняя ошибка на aliens_data: 0.0268
# Минимальная ошибка на aliens_data: 0.0268
# Средняя ошибка на aliens_data: 0.0438
# Минимальная ошибка на aliens_data: 0.0438
# Средняя ошибка на aliens_data: 0.0348
# Минимальная ошибка на aliens_data: 0.0348
# Средняя ошибка на aliens_data: 0.0385
# Минимальная ошибка на aliens_data: 0.0385
# Средняя ошибка на aliens_data: 0.0294
# Минимальная ошибка на aliens_data: 0.0294
# Средняя ошибка на aliens_data: 0.0628
# Минимальная ошибка на aliens_data: 0.0628
# Средняя ошибка на aliens_data: 0.0543
# Минимальная ошибка на aliens_data: 0.0543
# Средняя ошибка на aliens_data: 0.0304
# Минимальная ошибка на aliens_data: 0.0304
# Средняя ошибка на aliens_data: 0.0447
# Минимальная ошибка на aliens_data: 0.0447
# Средняя ошибка на aliens_data: 0.0619
# Минимальная ошибка на aliens_data: 0.0619
# Средняя ошибка на aliens_data: 0.0389
# Минимальная ошибка на aliens_data: 0.0389
# Средняя ошибка на aliens_data: 0.0523
# Минимальная ошибка на aliens_data: 0.0523
# Средняя ошибка на aliens_data: 0.0578
# Минимальная ошибка на aliens_data: 0.0578
# Средняя ошибка на aliens_data: 0.0469
# Минимальная ошибка на aliens_data: 0.0469
# Средняя ошибка на aliens_data: 0.1776
# Минимальная ошибка на aliens_data: 0.1776
# Средняя ошибка на aliens_data: 0.0332
# Минимальная ошибка на aliens_data: 0.0332
# Средняя ошибка на aliens_data: 0.0692
# Минимальная ошибка на aliens_data: 0.0692
# Средняя ошибка на aliens_data: 0.0244
# Минимальная ошибка на aliens_data: 0.0244
# Средняя ошибка на aliens_data: 0.0402
# Минимальная ошибка на aliens_data: 0.0402
# Средняя ошибка на aliens_data: 0.0238
# Минимальная ошибка на aliens_data: 0.0238
# Средняя ошибка на aliens_data: 0.1184
# Минимальная ошибка на aliens_data: 0.1184
# Средняя ошибка на aliens_data: 0.0529
# Минимальная ошибка на aliens_data: 0.0529
# Средняя ошибка на aliens_data: 0.0509
# Минимальная ошибка на aliens_data: 0.0509
# Средняя ошибка на aliens_data: 0.0513
# Минимальная ошибка на aliens_data: 0.0513
# Средняя ошибка на aliens_data: 0.0461
# Минимальная ошибка на aliens_data: 0.0461
# Средняя ошибка на aliens_data: 0.025
# Минимальная ошибка на aliens_data: 0.025
# Средняя ошибка на aliens_data: 0.035
# Минимальная ошибка на aliens_data: 0.035
# Средняя ошибка на aliens_data: 0.0216
# Минимальная ошибка на aliens_data: 0.0216
# Средняя ошибка на aliens_data: 0.0309
# Минимальная ошибка на aliens_data: 0.0309
# Средняя ошибка на aliens_data: 0.0305
# Минимальная ошибка на aliens_data: 0.0305
# Средняя ошибка на aliens_data: 0.0969
# Минимальная ошибка на aliens_data: 0.0969
# Средняя ошибка на aliens_data: 0.0324
# Минимальная ошибка на aliens_data: 0.0324
# Средняя ошибка на aliens_data: 0.081
# Минимальная ошибка на aliens_data: 0.081
# Средняя ошибка на aliens_data: 0.0636
# Минимальная ошибка на aliens_data: 0.0636
# Средняя ошибка на aliens_data: 0.0638
# Минимальная ошибка на aliens_data: 0.0638
# Средняя ошибка на aliens_data: 0.062
# Минимальная ошибка на aliens_data: 0.062
# Средняя ошибка на aliens_data: 0.0498
# Минимальная ошибка на aliens_data: 0.0498
# Средняя ошибка на aliens_data: 0.0282
# Минимальная ошибка на aliens_data: 0.0282
# Средняя ошибка на aliens_data: 0.047
# Минимальная ошибка на aliens_data: 0.047
# Средняя ошибка на aliens_data: 0.044
# Минимальная ошибка на aliens_data: 0.044
# Средняя ошибка на aliens_data: 0.0147
# Минимальная ошибка на aliens_data: 0.0147
# Средняя ошибка на aliens_data: 0.0492
# Минимальная ошибка на aliens_data: 0.0492
# Средняя ошибка на aliens_data: 0.0337
# Минимальная ошибка на aliens_data: 0.0337
# Средняя ошибка на aliens_data: 0.0261
# Минимальная ошибка на aliens_data: 0.0261
# Средняя ошибка на aliens_data: 0.0469
# Минимальная ошибка на aliens_data: 0.0469
# Средняя ошибка на aliens_data: 0.0245
# Минимальная ошибка на aliens_data: 0.0245
# Средняя ошибка на aliens_data: 0.062
# Минимальная ошибка на aliens_data: 0.062
# Средняя ошибка на aliens_data: 0.0605
# Минимальная ошибка на aliens_data: 0.0605
# Средняя ошибка на aliens_data: 0.0388
# Минимальная ошибка на aliens_data: 0.0388
# Средняя ошибка на aliens_data: 0.041
# Минимальная ошибка на aliens_data: 0.0331
# Средняя ошибка на aliens_data: 0.0487
# Минимальная ошибка на aliens_data: 0.0473
# Средняя ошибка на aliens_data: 0.0133
# Минимальная ошибка на aliens_data: 0.0133
# Средняя ошибка на aliens_data: 0.021
# Минимальная ошибка на aliens_data: 0.021
# Средняя ошибка на aliens_data: 0.0175
# Минимальная ошибка на aliens_data: 0.0175
# Средняя ошибка на aliens_data: 0.0485
# Минимальная ошибка на aliens_data: 0.0485
# Средняя ошибка на aliens_data: 0.0829
# Минимальная ошибка на aliens_data: 0.0829
# Средняя ошибка на aliens_data: 0.0146
# Минимальная ошибка на aliens_data: 0.0146
# Средняя ошибка на aliens_data: 0.0203
# Минимальная ошибка на aliens_data: 0.0203
# Средняя ошибка на aliens_data: 0.0352
# Минимальная ошибка на aliens_data: 0.0352
# Средняя ошибка на aliens_data: 0.1135
# Минимальная ошибка на aliens_data: 0.1135
# Средняя ошибка на aliens_data: 0.0651
# Минимальная ошибка на aliens_data: 0.0455
# Средняя ошибка на aliens_data: 0.0569
# Минимальная ошибка на aliens_data: 0.0569
# Средняя ошибка на aliens_data: 0.0212
# Минимальная ошибка на aliens_data: 0.0212
# Средняя ошибка на aliens_data: 0.0704
# Минимальная ошибка на aliens_data: 0.0704
# Средняя ошибка на aliens_data: 0.0304
# Минимальная ошибка на aliens_data: 0.0304
# Средняя ошибка на aliens_data: 0.0881
# Минимальная ошибка на aliens_data: 0.0881
# Средняя ошибка на aliens_data: 0.0204
# Минимальная ошибка на aliens_data: 0.0204
# Средняя ошибка на aliens_data: 0.0369
# Минимальная ошибка на aliens_data: 0.0369
# Средняя ошибка на aliens_data: 0.0784
# Минимальная ошибка на aliens_data: 0.0784
# Средняя ошибка на aliens_data: 0.0948
# Минимальная ошибка на aliens_data: 0.0948
# Средняя ошибка на aliens_data: 0.0468
# Минимальная ошибка на aliens_data: 0.0468
# Средняя ошибка на aliens_data: 0.0252
# Минимальная ошибка на aliens_data: 0.0252
# Средняя ошибка на aliens_data: 0.0302
# Минимальная ошибка на aliens_data: 0.0302
# Средняя ошибка на aliens_data: 0.0331
# Минимальная ошибка на aliens_data: 0.0331
# Средняя ошибка на aliens_data: 0.117
# Минимальная ошибка на aliens_data: 0.117
# Средняя ошибка на aliens_data: 0.0236
# Минимальная ошибка на aliens_data: 0.0236
# Средняя ошибка на aliens_data: 0.0337
# Минимальная ошибка на aliens_data: 0.0337
# Средняя ошибка на aliens_data: 0.079
# Минимальная ошибка на aliens_data: 0.079
# Средняя ошибка на aliens_data: 0.032
# Минимальная ошибка на aliens_data: 0.032
# Средняя ошибка на aliens_data: 0.0284
# Минимальная ошибка на aliens_data: 0.0284
# Средняя ошибка на aliens_data: 0.0446
# Минимальная ошибка на aliens_data: 0.0446
# Средняя ошибка на aliens_data: 0.0749
# Минимальная ошибка на aliens_data: 0.0749
# Средняя ошибка на aliens_data: 0.0319
# Минимальная ошибка на aliens_data: 0.0319
# Средняя ошибка на aliens_data: 0.0582
# Минимальная ошибка на aliens_data: 0.0405
# Средняя ошибка на aliens_data: 0.0492
# Минимальная ошибка на aliens_data: 0.027
# Средняя ошибка на aliens_data: 0.1013
# Минимальная ошибка на aliens_data: 0.1013
# Средняя ошибка на aliens_data: 0.0732
# Минимальная ошибка на aliens_data: 0.032
# Средняя ошибка на aliens_data: 0.0244
# Минимальная ошибка на aliens_data: 0.0244
# Средняя ошибка на aliens_data: 0.0426
# Минимальная ошибка на aliens_data: 0.0426
# Средняя ошибка на aliens_data: 0.1023
# Минимальная ошибка на aliens_data: 0.1023
# Средняя ошибка на aliens_data: 0.0422
# Минимальная ошибка на aliens_data: 0.0422
# Средняя ошибка на aliens_data: 0.0429
# Минимальная ошибка на aliens_data: 0.0429
# Средняя ошибка на aliens_data: 0.0435
# Минимальная ошибка на aliens_data: 0.0435
# Средняя ошибка на aliens_data: 0.055
# Минимальная ошибка на aliens_data: 0.055
# Средняя ошибка на aliens_data: 0.0276
# Минимальная ошибка на aliens_data: 0.0276
# Средняя ошибка на aliens_data: 0.0555
# Минимальная ошибка на aliens_data: 0.0555
# Средняя ошибка на aliens_data: 0.0614
# Минимальная ошибка на aliens_data: 0.0614
# Средняя ошибка на aliens_data: 0.0531
# Минимальная ошибка на aliens_data: 0.0531
# Средняя ошибка на aliens_data: 0.0244
# Минимальная ошибка на aliens_data: 0.0244
# Средняя ошибка на aliens_data: 0.0197
# Минимальная ошибка на aliens_data: 0.0197
# Средняя ошибка на aliens_data: 0.0356
# Минимальная ошибка на aliens_data: 0.0356
# Средняя ошибка на aliens_data: 0.0384
# Минимальная ошибка на aliens_data: 0.0384
# Средняя ошибка на aliens_data: 0.0392
# Минимальная ошибка на aliens_data: 0.0392
# Средняя ошибка на aliens_data: 0.0322
# Минимальная ошибка на aliens_data: 0.0322
# Средняя ошибка на aliens_data: 0.0131
# Минимальная ошибка на aliens_data: 0.0131
# Средняя ошибка на aliens_data: 0.04
# Минимальная ошибка на aliens_data: 0.04
# Средняя ошибка на aliens_data: 0.0229
# Минимальная ошибка на aliens_data: 0.0229
# Средняя ошибка на aliens_data: 0.1651
# Минимальная ошибка на aliens_data: 0.1651
# Средняя ошибка на aliens_data: 0.0372
# Минимальная ошибка на aliens_data: 0.0372
# Средняя ошибка на aliens_data: 0.0197
# Минимальная ошибка на aliens_data: 0.0197
# Средняя ошибка на aliens_data: 0.0291
# Минимальная ошибка на aliens_data: 0.0291
# Средняя ошибка на aliens_data: 0.1652
# Минимальная ошибка на aliens_data: 0.1652
# Средняя ошибка на aliens_data: 0.0459
# Минимальная ошибка на aliens_data: 0.0459
# Средняя ошибка на aliens_data: 0.0329
# Минимальная ошибка на aliens_data: 0.0329
# Средняя ошибка на aliens_data: 0.0872
# Минимальная ошибка на aliens_data: 0.0872
# Средняя ошибка на aliens_data: 0.0402
# Минимальная ошибка на aliens_data: 0.0402
# Средняя ошибка на aliens_data: 0.0508
# Минимальная ошибка на aliens_data: 0.0508
# Средняя ошибка на aliens_data: 0.1721
# Минимальная ошибка на aliens_data: 0.1721
# Средняя ошибка на aliens_data: 0.0442
# Минимальная ошибка на aliens_data: 0.0442
# Средняя ошибка на aliens_data: 0.0275
# Минимальная ошибка на aliens_data: 0.0275
# Средняя ошибка на aliens_data: 0.0429
# Минимальная ошибка на aliens_data: 0.0429
# Средняя ошибка на aliens_data: 0.0482
# Минимальная ошибка на aliens_data: 0.0482
# Средняя ошибка на aliens_data: 0.0542
# Минимальная ошибка на aliens_data: 0.0542
# Средняя ошибка на aliens_data: 0.0622
# Минимальная ошибка на aliens_data: 0.0622
# Средняя ошибка на aliens_data: 0.0454
# Минимальная ошибка на aliens_data: 0.0454
# Средняя ошибка на aliens_data: 0.0353
# Минимальная ошибка на aliens_data: 0.0353
# Средняя ошибка на aliens_data: 0.0324
# Минимальная ошибка на aliens_data: 0.0324
# Средняя ошибка на aliens_data: 0.0182
# Минимальная ошибка на aliens_data: 0.0182
# Средняя ошибка на aliens_data: 0.022
# Минимальная ошибка на aliens_data: 0.022
# Средняя ошибка на aliens_data: 0.0586
# Минимальная ошибка на aliens_data: 0.0586
# Средняя ошибка на aliens_data: 0.0202
# Минимальная ошибка на aliens_data: 0.0202
# Средняя ошибка на aliens_data: 0.0202
# Минимальная ошибка на aliens_data: 0.0202
# Средняя ошибка на aliens_data: 0.0166
# Минимальная ошибка на aliens_data: 0.0166
# Средняя ошибка на aliens_data: 0.058
# Минимальная ошибка на aliens_data: 0.0279
# Средняя ошибка на aliens_data: 0.0486
# Минимальная ошибка на aliens_data: 0.0326
# Средняя ошибка на aliens_data: 0.0482
# Минимальная ошибка на aliens_data: 0.0226
# Средняя ошибка на aliens_data: 0.0254
# Минимальная ошибка на aliens_data: 0.0228
# Средняя ошибка на aliens_data: 0.0363
# Минимальная ошибка на aliens_data: 0.036
# Средняя ошибка на aliens_data: 0.051
# Минимальная ошибка на aliens_data: 0.0482
# Средняя ошибка на aliens_data: 0.0816
# Минимальная ошибка на aliens_data: 0.0757
# Средняя ошибка на aliens_data: 0.0305
# Минимальная ошибка на aliens_data: 0.0263
# Средняя ошибка на aliens_data: 0.0716
# Минимальная ошибка на aliens_data: 0.0392
# Средняя ошибка на aliens_data: 0.0907
# Минимальная ошибка на aliens_data: 0.0335
# Средняя ошибка на aliens_data: 0.0576
# Минимальная ошибка на aliens_data: 0.0391
# Средняя ошибка на aliens_data: 0.0334
# Минимальная ошибка на aliens_data: 0.0321
# Средняя ошибка на aliens_data: 0.0309
# Минимальная ошибка на aliens_data: 0.0227
# Средняя ошибка на aliens_data: 0.047
# Минимальная ошибка на aliens_data: 0.0283
# Средняя ошибка на aliens_data: 0.0492
# Минимальная ошибка на aliens_data: 0.0195
# Средняя ошибка на aliens_data: 0.0458
# Минимальная ошибка на aliens_data: 0.0254
# Средняя ошибка на aliens_data: 0.0286
# Минимальная ошибка на aliens_data: 0.0218
# Средняя ошибка на aliens_data: 0.0392
# Минимальная ошибка на aliens_data: 0.0265
# Средняя ошибка на aliens_data: 0.0767
# Минимальная ошибка на aliens_data: 0.0551
# Средняя ошибка на aliens_data: 0.0264
# Минимальная ошибка на aliens_data: 0.0215
# Средняя ошибка на aliens_data: 0.0253
# Минимальная ошибка на aliens_data: 0.0248
# Средняя ошибка на aliens_data: 0.0382
# Минимальная ошибка на aliens_data: 0.0251
# Средняя ошибка на aliens_data: 0.0709
# Минимальная ошибка на aliens_data: 0.0391
# Средняя ошибка на aliens_data: 0.0396
# Минимальная ошибка на aliens_data: 0.0286
# Средняя ошибка на aliens_data: 0.0553
# Минимальная ошибка на aliens_data: 0.034
# Средняя ошибка на aliens_data: 0.0301
# Минимальная ошибка на aliens_data: 0.0203
# Средняя ошибка на aliens_data: 0.041
# Минимальная ошибка на aliens_data: 0.0303
# Средняя ошибка на aliens_data: 0.0348
# Минимальная ошибка на aliens_data: 0.0236
# Средняя ошибка на aliens_data: 0.0349
# Минимальная ошибка на aliens_data: 0.0181
# Средняя ошибка на aliens_data: 0.0427
# Минимальная ошибка на aliens_data: 0.0284
# Средняя ошибка на aliens_data: 0.0427
# Минимальная ошибка на aliens_data: 0.0237
# Средняя ошибка на aliens_data: 0.0632
# Минимальная ошибка на aliens_data: 0.0348
# Средняя ошибка на aliens_data: 0.027
# Минимальная ошибка на aliens_data: 0.0159
# Средняя ошибка на aliens_data: 0.0307
# Минимальная ошибка на aliens_data: 0.0172
# Средняя ошибка на aliens_data: 0.0582
# Минимальная ошибка на aliens_data: 0.0247
# Средняя ошибка на aliens_data: 0.068
# Минимальная ошибка на aliens_data: 0.0364
# Средняя ошибка на aliens_data: 0.046
# Минимальная ошибка на aliens_data: 0.0306
# Средняя ошибка на aliens_data: 0.0515
# Минимальная ошибка на aliens_data: 0.0273
# Средняя ошибка на aliens_data: 0.0389
# Минимальная ошибка на aliens_data: 0.0272
# Средняя ошибка на aliens_data: 0.0428
# Минимальная ошибка на aliens_data: 0.0141
# Средняя ошибка на aliens_data: 0.04
# Минимальная ошибка на aliens_data: 0.0085
# Средняя ошибка на aliens_data: 0.0483
# Минимальная ошибка на aliens_data: 0.0275
# Средняя ошибка на aliens_data: 0.032
# Минимальная ошибка на aliens_data: 0.0173
# Средняя ошибка на aliens_data: 0.0337
# Минимальная ошибка на aliens_data: 0.0246
# Средняя ошибка на aliens_data: 0.0652
# Минимальная ошибка на aliens_data: 0.0258
# Средняя ошибка на aliens_data: 0.0318
# Минимальная ошибка на aliens_data: 0.0221
# Средняя ошибка на aliens_data: 0.058
# Минимальная ошибка на aliens_data: 0.0182
# Средняя ошибка на aliens_data: 0.0454
# Минимальная ошибка на aliens_data: 0.032
# Средняя ошибка на aliens_data: 0.0547
# Минимальная ошибка на aliens_data: 0.0193
# Средняя ошибка на aliens_data: 0.0239
# Минимальная ошибка на aliens_data: 0.0206
# Средняя ошибка на aliens_data: 0.0502
# Минимальная ошибка на aliens_data: 0.0138
# Средняя ошибка на aliens_data: 0.0322
# Минимальная ошибка на aliens_data: 0.0275
# Средняя ошибка на aliens_data: 0.0944
# Минимальная ошибка на aliens_data: 0.0501
# Средняя ошибка на aliens_data: 0.0342
# Минимальная ошибка на aliens_data: 0.0217
# Средняя ошибка на aliens_data: 0.0523
# Минимальная ошибка на aliens_data: 0.0282
# Средняя ошибка на aliens_data: 0.0294
# Минимальная ошибка на aliens_data: 0.0257
# Средняя ошибка на aliens_data: 0.0414
# Минимальная ошибка на aliens_data: 0.0227
# Средняя ошибка на aliens_data: 0.0528
# Минимальная ошибка на aliens_data: 0.0292
# Средняя ошибка на aliens_data: 0.0313
# Минимальная ошибка на aliens_data: 0.0184
# Средняя ошибка на aliens_data: 0.0498
# Минимальная ошибка на aliens_data: 0.0466
# Средняя ошибка на aliens_data: 0.0237
# Минимальная ошибка на aliens_data: 0.0169
# Средняя ошибка на aliens_data: 0.0271
# Минимальная ошибка на aliens_data: 0.0144
# Средняя ошибка на aliens_data: 0.0538
# Минимальная ошибка на aliens_data: 0.0213
# Средняя ошибка на aliens_data: 0.0463
# Минимальная ошибка на aliens_data: 0.0188
# Средняя ошибка на aliens_data: 0.0534
# Минимальная ошибка на aliens_data: 0.0325
# Средняя ошибка на aliens_data: 0.0359
# Минимальная ошибка на aliens_data: 0.0312
# Средняя ошибка на aliens_data: 0.0581
# Минимальная ошибка на aliens_data: 0.0269
# Средняя ошибка на aliens_data: 0.0291
# Минимальная ошибка на aliens_data: 0.0215
# Средняя ошибка на aliens_data: 0.0386
# Минимальная ошибка на aliens_data: 0.0322
# Средняя ошибка на aliens_data: 0.028
# Минимальная ошибка на aliens_data: 0.0251
# Средняя ошибка на aliens_data: 0.0404
# Минимальная ошибка на aliens_data: 0.0322
# Средняя ошибка на aliens_data: 0.0609
# Минимальная ошибка на aliens_data: 0.034
# Средняя ошибка на aliens_data: 0.0886
# Минимальная ошибка на aliens_data: 0.0488
# Средняя ошибка на aliens_data: 0.0487
# Минимальная ошибка на aliens_data: 0.0327
# Средняя ошибка на aliens_data: 0.0483
# Минимальная ошибка на aliens_data: 0.0364
# Средняя ошибка на aliens_data: 0.0533
# Минимальная ошибка на aliens_data: 0.044
# Средняя ошибка на aliens_data: 0.0713
# Минимальная ошибка на aliens_data: 0.0516
# Средняя ошибка на aliens_data: 0.0208
# Минимальная ошибка на aliens_data: 0.017
# Средняя ошибка на aliens_data: 0.0415
# Минимальная ошибка на aliens_data: 0.0074
# Средняя ошибка на aliens_data: 0.0282
# Минимальная ошибка на aliens_data: 0.0211
# Средняя ошибка на aliens_data: 0.0291
# Минимальная ошибка на aliens_data: 0.0164
# Средняя ошибка на aliens_data: 0.0359
# Минимальная ошибка на aliens_data: 0.0303
# Средняя ошибка на aliens_data: 0.0315
# Минимальная ошибка на aliens_data: 0.0294
# Средняя ошибка на aliens_data: 0.0646
# Минимальная ошибка на aliens_data: 0.0118
# Средняя ошибка на aliens_data: 0.0365
# Минимальная ошибка на aliens_data: 0.03
# Средняя ошибка на aliens_data: 0.0493
# Минимальная ошибка на aliens_data: 0.0427
# Средняя ошибка на aliens_data: 0.0295
# Минимальная ошибка на aliens_data: 0.0189
# Средняя ошибка на aliens_data: 0.0309
# Минимальная ошибка на aliens_data: 0.0244
# Средняя ошибка на aliens_data: 0.0673
# Минимальная ошибка на aliens_data: 0.0216
# Средняя ошибка на aliens_data: 0.0411
# Минимальная ошибка на aliens_data: 0.0231
# Средняя ошибка на aliens_data: 0.0666
# Минимальная ошибка на aliens_data: 0.0241
# Средняя ошибка на aliens_data: 0.0539
# Минимальная ошибка на aliens_data: 0.0346
# Средняя ошибка на aliens_data: 0.0293
# Минимальная ошибка на aliens_data: 0.022
# Средняя ошибка на aliens_data: 0.0653
# Минимальная ошибка на aliens_data: 0.0196
# Средняя ошибка на aliens_data: 0.0919
# Минимальная ошибка на aliens_data: 0.0323
# Средняя ошибка на aliens_data: 0.067
# Минимальная ошибка на aliens_data: 0.031
# Средняя ошибка на aliens_data: 0.0461
# Минимальная ошибка на aliens_data: 0.0429
# Средняя ошибка на aliens_data: 0.0403
# Минимальная ошибка на aliens_data: 0.0221
# Средняя ошибка на aliens_data: 0.0629
# Минимальная ошибка на aliens_data: 0.0331
# Средняя ошибка на aliens_data: 0.0595
# Минимальная ошибка на aliens_data: 0.0248
# Средняя ошибка на aliens_data: 0.0389
# Минимальная ошибка на aliens_data: 0.0334
# Средняя ошибка на aliens_data: 0.0349
# Минимальная ошибка на aliens_data: 0.0286
# Средняя ошибка на aliens_data: 0.0465
# Минимальная ошибка на aliens_data: 0.0269
# Средняя ошибка на aliens_data: 0.0498
# Минимальная ошибка на aliens_data: 0.0263
# Средняя ошибка на aliens_data: 0.0477
# Минимальная ошибка на aliens_data: 0.0237
# Средняя ошибка на aliens_data: 0.027
# Минимальная ошибка на aliens_data: 0.016
# Средняя ошибка на aliens_data: 0.0385
# Минимальная ошибка на aliens_data: 0.0192
# Средняя ошибка на aliens_data: 0.04
# Минимальная ошибка на aliens_data: 0.0195
# Средняя ошибка на aliens_data: 0.047
# Минимальная ошибка на aliens_data: 0.0275
# Средняя ошибка на aliens_data: 0.0393
# Минимальная ошибка на aliens_data: 0.0191
# Средняя ошибка на aliens_data: 0.0565
# Минимальная ошибка на aliens_data: 0.0509
# Средняя ошибка на aliens_data: 0.0352
# Минимальная ошибка на aliens_data: 0.0179
# Средняя ошибка на aliens_data: 0.0525
# Минимальная ошибка на aliens_data: 0.0203
# Средняя ошибка на aliens_data: 0.0296
# Минимальная ошибка на aliens_data: 0.0197
# Средняя ошибка на aliens_data: 0.0467
# Минимальная ошибка на aliens_data: 0.0418
# Средняя ошибка на aliens_data: 0.0433
# Минимальная ошибка на aliens_data: 0.0408
# Средняя ошибка на aliens_data: 0.0304
# Минимальная ошибка на aliens_data: 0.0225
# Средняя ошибка на aliens_data: 0.0787
# Минимальная ошибка на aliens_data: 0.0175
# Средняя ошибка на aliens_data: 0.0335
# Минимальная ошибка на aliens_data: 0.0271
# Средняя ошибка на aliens_data: 0.038
# Минимальная ошибка на aliens_data: 0.0175
# Средняя ошибка на aliens_data: 0.0794
# Минимальная ошибка на aliens_data: 0.034
# Средняя ошибка на aliens_data: 0.0267
# Минимальная ошибка на aliens_data: 0.0155
# Средняя ошибка на aliens_data: 0.0491
# Минимальная ошибка на aliens_data: 0.0171
# Средняя ошибка на aliens_data: 0.0532
# Минимальная ошибка на aliens_data: 0.0293
# Средняя ошибка на aliens_data: 0.0516
# Минимальная ошибка на aliens_data: 0.0196
# Средняя ошибка на aliens_data: 0.0372
# Минимальная ошибка на aliens_data: 0.0282
# Средняя ошибка на aliens_data: 0.0388
# Минимальная ошибка на aliens_data: 0.035
# Средняя ошибка на aliens_data: 0.0648
# Минимальная ошибка на aliens_data: 0.0175
# Средняя ошибка на aliens_data: 0.03
# Минимальная ошибка на aliens_data: 0.0269
# Средняя ошибка на aliens_data: 0.0309
# Минимальная ошибка на aliens_data: 0.0183
# Средняя ошибка на aliens_data: 0.0565
# Минимальная ошибка на aliens_data: 0.014
# Средняя ошибка на aliens_data: 0.0361
# Минимальная ошибка на aliens_data: 0.0152
# ...
# Средняя ошибка на aliens_data: 0.0663
# Минимальная ошибка на aliens_data: 0.0523
# Средняя ошибка на aliens_data: 0.0727
# Минимальная ошибка на aliens_data: 0.0727
# Средняя ошибка на aliens_data: 0.0488
# Минимальная ошибка на aliens_data: 0.0332
# Средняя ошибка на aliens_data: 0.0688
# Минимальная ошибка на aliens_data: 0.0688
# Средняя ошибка на aliens_data: 0.0873
# Минимальная ошибка на aliens_data: 0.0737
# Средняя ошибка на aliens_data: 0.0724
# Минимальная ошибка на aliens_data: 0.0383
# Средняя ошибка на aliens_data: 0.0893
# Минимальная ошибка на aliens_data: 0.0735
# Средняя ошибка на aliens_data: 0.0907
# Минимальная ошибка на aliens_data: 0.0774
# Средняя ошибка на aliens_data: 0.0656
# Минимальная ошибка на aliens_data: 0.0648
# Средняя ошибка на aliens_data: 0.0759
# Минимальная ошибка на aliens_data: 0.0587
# Средняя ошибка на aliens_data: 0.073
# Минимальная ошибка на aliens_data: 0.073
# Средняя ошибка на aliens_data: 0.0785
# Минимальная ошибка на aliens_data: 0.0785
# Средняя ошибка на aliens_data: 0.0317
# Минимальная ошибка на aliens_data: 0.0317
# Средняя ошибка на aliens_data: 0.0441
# Минимальная ошибка на aliens_data: 0.0441
# Средняя ошибка на aliens_data: 0.0421
# Минимальная ошибка на aliens_data: 0.0421
# Средняя ошибка на aliens_data: 0.0473
# Минимальная ошибка на aliens_data: 0.0473
# Средняя ошибка на aliens_data: 0.0972
# Минимальная ошибка на aliens_data: 0.0489
# Средняя ошибка на aliens_data: 0.1697
# Минимальная ошибка на aliens_data: 0.1697
# Средняя ошибка на aliens_data: 0.1947
# Минимальная ошибка на aliens_data: 0.1947
# Средняя ошибка на aliens_data: 0.1252
# Минимальная ошибка на aliens_data: 0.1252
# Средняя ошибка на aliens_data: 0.234
# Минимальная ошибка на aliens_data: 0.234
# Средняя ошибка на aliens_data: 0.0461
# Минимальная ошибка на aliens_data: 0.0461
# Средняя ошибка на aliens_data: 0.0879
# Минимальная ошибка на aliens_data: 0.0692
# Средняя ошибка на aliens_data: 0.0377
# Минимальная ошибка на aliens_data: 0.0377
# Средняя ошибка на aliens_data: 0.0228
# Минимальная ошибка на aliens_data: 0.0228
# Средняя ошибка на aliens_data: 0.062
# Минимальная ошибка на aliens_data: 0.062
# Средняя ошибка на aliens_data: 0.0324
# Минимальная ошибка на aliens_data: 0.0324
# Средняя ошибка на aliens_data: 0.1223
# Минимальная ошибка на aliens_data: 0.1223
# Средняя ошибка на aliens_data: 0.021
# Минимальная ошибка на aliens_data: 0.021
# Средняя ошибка на aliens_data: 0.0755
# Минимальная ошибка на aliens_data: 0.04
# Средняя ошибка на aliens_data: 0.0504
# Минимальная ошибка на aliens_data: 0.0484
# Средняя ошибка на aliens_data: 0.0592
# Минимальная ошибка на aliens_data: 0.0388
# Средняя ошибка на aliens_data: 0.0978
# Минимальная ошибка на aliens_data: 0.0978
# Средняя ошибка на aliens_data: 0.0707
# Минимальная ошибка на aliens_data: 0.0707
# Средняя ошибка на aliens_data: 0.0437
# Минимальная ошибка на aliens_data: 0.0437
# Средняя ошибка на aliens_data: 0.053
# Минимальная ошибка на aliens_data: 0.0515
# Средняя ошибка на aliens_data: 0.0925
# Минимальная ошибка на aliens_data: 0.0925
# Средняя ошибка на aliens_data: 0.0402
# Минимальная ошибка на aliens_data: 0.0402
# Средняя ошибка на aliens_data: 0.0607
# Минимальная ошибка на aliens_data: 0.0607
# Средняя ошибка на aliens_data: 0.0663
# Минимальная ошибка на aliens_data: 0.0663
# Средняя ошибка на aliens_data: 0.0557
# Минимальная ошибка на aliens_data: 0.0322
# Средняя ошибка на aliens_data: 0.0492
# Минимальная ошибка на aliens_data: 0.0427
# Средняя ошибка на aliens_data: 0.0441
# Минимальная ошибка на aliens_data: 0.0441
# Средняя ошибка на aliens_data: 0.0691
# Минимальная ошибка на aliens_data: 0.0691
# Средняя ошибка на aliens_data: 0.0321
# Минимальная ошибка на aliens_data: 0.0321
# Средняя ошибка на aliens_data: 0.0399
# Минимальная ошибка на aliens_data: 0.0257
# Средняя ошибка на aliens_data: 0.0472
# Минимальная ошибка на aliens_data: 0.0364
# Средняя ошибка на aliens_data: 0.0426
# Минимальная ошибка на aliens_data: 0.0324
# Средняя ошибка на aliens_data: 0.0464
# Минимальная ошибка на aliens_data: 0.0239
# Средняя ошибка на aliens_data: 0.0606
# Минимальная ошибка на aliens_data: 0.0505
# Средняя ошибка на aliens_data: 0.0419
# Минимальная ошибка на aliens_data: 0.038
# Средняя ошибка на aliens_data: 0.0514
# Минимальная ошибка на aliens_data: 0.0322
# Средняя ошибка на aliens_data: 0.0499
# Минимальная ошибка на aliens_data: 0.0289
# Средняя ошибка на aliens_data: 0.1091
# Минимальная ошибка на aliens_data: 0.0683
# Средняя ошибка на aliens_data: 0.0396
# Минимальная ошибка на aliens_data: 0.0262
# Средняя ошибка на aliens_data: 0.0754
# Минимальная ошибка на aliens_data: 0.0392
# Средняя ошибка на aliens_data: 0.048
# Минимальная ошибка на aliens_data: 0.0222
# Средняя ошибка на aliens_data: 0.0377
# Минимальная ошибка на aliens_data: 0.0355
# Средняя ошибка на aliens_data: 0.0495
# Минимальная ошибка на aliens_data: 0.0454
# Средняя ошибка на aliens_data: 0.0478
# Минимальная ошибка на aliens_data: 0.0463
# Средняя ошибка на aliens_data: 0.0822
# Минимальная ошибка на aliens_data: 0.0566
# Средняя ошибка на aliens_data: 0.0704
# Минимальная ошибка на aliens_data: 0.0551
# Средняя ошибка на aliens_data: 0.1415
# Минимальная ошибка на aliens_data: 0.1415
# Средняя ошибка на aliens_data: 0.0777
# Минимальная ошибка на aliens_data: 0.0465
# Средняя ошибка на aliens_data: 0.1015
# Минимальная ошибка на aliens_data: 0.1015
# Средняя ошибка на aliens_data: 0.101
# Минимальная ошибка на aliens_data: 0.0925
# Средняя ошибка на aliens_data: 0.1882
# Минимальная ошибка на aliens_data: 0.1812
# Средняя ошибка на aliens_data: 0.1269
# Минимальная ошибка на aliens_data: 0.1095
# Средняя ошибка на aliens_data: 0.0546
# Минимальная ошибка на aliens_data: 0.0546
# Средняя ошибка на aliens_data: 0.0691
# Минимальная ошибка на aliens_data: 0.0691
# Средняя ошибка на aliens_data: 0.096
# Минимальная ошибка на aliens_data: 0.096
# Средняя ошибка на aliens_data: 0.0628
# Минимальная ошибка на aliens_data: 0.0406
# Средняя ошибка на aliens_data: 0.0973
# Минимальная ошибка на aliens_data: 0.0765
# Средняя ошибка на aliens_data: 0.0907
# Минимальная ошибка на aliens_data: 0.0816
# Средняя ошибка на aliens_data: 0.0882
# Минимальная ошибка на aliens_data: 0.0837
# Средняя ошибка на aliens_data: 0.0584
# Минимальная ошибка на aliens_data: 0.0416
# Средняя ошибка на aliens_data: 0.0664
# Минимальная ошибка на aliens_data: 0.0664
# Средняя ошибка на aliens_data: 0.0385
# Минимальная ошибка на aliens_data: 0.0385
# Средняя ошибка на aliens_data: 0.0604
# Минимальная ошибка на aliens_data: 0.0604
# Средняя ошибка на aliens_data: 0.0598
# Минимальная ошибка на aliens_data: 0.0598
# Средняя ошибка на aliens_data: 0.0601
# Минимальная ошибка на aliens_data: 0.0601
# Средняя ошибка на aliens_data: 0.0444
# Минимальная ошибка на aliens_data: 0.0387
# Средняя ошибка на aliens_data: 0.0575
# Минимальная ошибка на aliens_data: 0.0575
# Средняя ошибка на aliens_data: 0.0844
# Минимальная ошибка на aliens_data: 0.0772
# Средняя ошибка на aliens_data: 0.0946
# Минимальная ошибка на aliens_data: 0.0807
# Средняя ошибка на aliens_data: 0.0565
# Минимальная ошибка на aliens_data: 0.0548
# Средняя ошибка на aliens_data: 0.0417
# Минимальная ошибка на aliens_data: 0.0384
# Средняя ошибка на aliens_data: 0.0759
# Минимальная ошибка на aliens_data: 0.0604
# Средняя ошибка на aliens_data: 0.0764
# Минимальная ошибка на aliens_data: 0.0584
# Средняя ошибка на aliens_data: 0.0672
# Минимальная ошибка на aliens_data: 0.0659
# Средняя ошибка на aliens_data: 0.0722
# Минимальная ошибка на aliens_data: 0.0595
# Средняя ошибка на aliens_data: 0.0779
# Минимальная ошибка на aliens_data: 0.0567
# Средняя ошибка на aliens_data: 0.0679
# Минимальная ошибка на aliens_data: 0.0679
# Средняя ошибка на aliens_data: 0.0666
# Минимальная ошибка на aliens_data: 0.0597
# Средняя ошибка на aliens_data: 0.0823
# Минимальная ошибка на aliens_data: 0.0752
# Средняя ошибка на aliens_data: 0.0657
# Минимальная ошибка на aliens_data: 0.0657
# Средняя ошибка на aliens_data: 0.0867
# Минимальная ошибка на aliens_data: 0.0769
# Средняя ошибка на aliens_data: 0.0908
# Минимальная ошибка на aliens_data: 0.0908
# Средняя ошибка на aliens_data: 0.0612
# Минимальная ошибка на aliens_data: 0.0446
# Средняя ошибка на aliens_data: 0.0557
# Минимальная ошибка на aliens_data: 0.0557
# Средняя ошибка на aliens_data: 0.053
# Минимальная ошибка на aliens_data: 0.053
# Средняя ошибка на aliens_data: 0.0508
# Минимальная ошибка на aliens_data: 0.0508
# Средняя ошибка на aliens_data: 0.058
# Минимальная ошибка на aliens_data: 0.058
# Средняя ошибка на aliens_data: 0.0426
# Минимальная ошибка на aliens_data: 0.0426
# Средняя ошибка на aliens_data: 0.0526
# Минимальная ошибка на aliens_data: 0.0526
# Средняя ошибка на aliens_data: 0.0536
# Минимальная ошибка на aliens_data: 0.0536
# Средняя ошибка на aliens_data: 0.0335
# Минимальная ошибка на aliens_data: 0.0335
# Средняя ошибка на aliens_data: 0.1012
# Минимальная ошибка на aliens_data: 0.0295
# Средняя ошибка на aliens_data: 0.0337
# Минимальная ошибка на aliens_data: 0.0317
# Средняя ошибка на aliens_data: 0.042
# Минимальная ошибка на aliens_data: 0.0315
# Средняя ошибка на aliens_data: 0.0491
# Минимальная ошибка на aliens_data: 0.0321
# Средняя ошибка на aliens_data: 0.0607
# Минимальная ошибка на aliens_data: 0.0497
# Средняя ошибка на aliens_data: 0.0408
# Минимальная ошибка на aliens_data: 0.0298
# Средняя ошибка на aliens_data: 0.0439
# Минимальная ошибка на aliens_data: 0.0408
# Средняя ошибка на aliens_data: 0.0727
# Минимальная ошибка на aliens_data: 0.0521
# Средняя ошибка на aliens_data: 0.0558
# Минимальная ошибка на aliens_data: 0.0507
# Средняя ошибка на aliens_data: 0.0543
# Минимальная ошибка на aliens_data: 0.0434
# Средняя ошибка на aliens_data: 0.041
# Минимальная ошибка на aliens_data: 0.0367
# Средняя ошибка на aliens_data: 0.0529
# Минимальная ошибка на aliens_data: 0.0529
# Средняя ошибка на aliens_data: 0.0611
# Минимальная ошибка на aliens_data: 0.0611
# Средняя ошибка на aliens_data: 0.0433
# Минимальная ошибка на aliens_data: 0.0229
# Средняя ошибка на aliens_data: 0.0442
# Минимальная ошибка на aliens_data: 0.0286
# Средняя ошибка на aliens_data: 0.0509
# Минимальная ошибка на aliens_data: 0.0435
# Средняя ошибка на aliens_data: 0.0489
# Минимальная ошибка на aliens_data: 0.0383
# Средняя ошибка на aliens_data: 0.0569
# Минимальная ошибка на aliens_data: 0.0448
# Средняя ошибка на aliens_data: 0.0431
# Минимальная ошибка на aliens_data: 0.0401
# Средняя ошибка на aliens_data: 0.0392
# Минимальная ошибка на aliens_data: 0.0331
# Средняя ошибка на aliens_data: 0.0581
# Минимальная ошибка на aliens_data: 0.0273
# Средняя ошибка на aliens_data: 0.0367
# Минимальная ошибка на aliens_data: 0.0329
# Средняя ошибка на aliens_data: 0.0727
# Минимальная ошибка на aliens_data: 0.0584
# Средняя ошибка на aliens_data: 0.0394
# Минимальная ошибка на aliens_data: 0.0344
# Средняя ошибка на aliens_data: 0.0893
# Минимальная ошибка на aliens_data: 0.0357
# Средняя ошибка на aliens_data: 0.1571
# Минимальная ошибка на aliens_data: 0.1571
# Средняя ошибка на aliens_data: 0.1286
# Минимальная ошибка на aliens_data: 0.1286
# Средняя ошибка на aliens_data: 0.0794
# Минимальная ошибка на aliens_data: 0.0309
# Средняя ошибка на aliens_data: 0.0267
# Минимальная ошибка на aliens_data: 0.0267
# Средняя ошибка на aliens_data: 0.0838
# Минимальная ошибка на aliens_data: 0.0356
# Средняя ошибка на aliens_data: 0.0585
# Минимальная ошибка на aliens_data: 0.0448
# Средняя ошибка на aliens_data: 0.0703
# Минимальная ошибка на aliens_data: 0.0517
# Средняя ошибка на aliens_data: 0.0401
# Минимальная ошибка на aliens_data: 0.0401
# Средняя ошибка на aliens_data: 0.0869
# Минимальная ошибка на aliens_data: 0.0869
# Средняя ошибка на aliens_data: 0.0777
# Минимальная ошибка на aliens_data: 0.053
# Средняя ошибка на aliens_data: 0.0545
# Минимальная ошибка на aliens_data: 0.0545
# Средняя ошибка на aliens_data: 0.123
# Минимальная ошибка на aliens_data: 0.123
# Средняя ошибка на aliens_data: 0.0755
# Минимальная ошибка на aliens_data: 0.0755
# Средняя ошибка на aliens_data: 0.0419
# Минимальная ошибка на aliens_data: 0.0419
# Средняя ошибка на aliens_data: 0.1285
# Минимальная ошибка на aliens_data: 0.1285
# Средняя ошибка на aliens_data: 0.0886
# Минимальная ошибка на aliens_data: 0.0548
# Средняя ошибка на aliens_data: 0.0521
# Минимальная ошибка на aliens_data: 0.0396
# Средняя ошибка на aliens_data: 0.0397
# Минимальная ошибка на aliens_data: 0.0237
# Средняя ошибка на aliens_data: 0.0291
# Минимальная ошибка на aliens_data: 0.0291
# Средняя ошибка на aliens_data: 0.117
# Минимальная ошибка на aliens_data: 0.0798
# Средняя ошибка на aliens_data: 0.0322
# Минимальная ошибка на aliens_data: 0.0266
# Средняя ошибка на aliens_data: 0.0753
# Минимальная ошибка на aliens_data: 0.0753
# Средняя ошибка на aliens_data: 0.0378
# Минимальная ошибка на aliens_data: 0.0358
# Средняя ошибка на aliens_data: 0.0429
# Минимальная ошибка на aliens_data: 0.0288
# Средняя ошибка на aliens_data: 0.049
# Минимальная ошибка на aliens_data: 0.0469
# Средняя ошибка на aliens_data: 0.1073
# Минимальная ошибка на aliens_data: 0.1073
# Средняя ошибка на aliens_data: 0.0992
# Минимальная ошибка на aliens_data: 0.0992
# Средняя ошибка на aliens_data: 0.0487
# Минимальная ошибка на aliens_data: 0.0487
# Средняя ошибка на aliens_data: 0.0249
# Минимальная ошибка на aliens_data: 0.0249
# Средняя ошибка на aliens_data: 0.0402
# Минимальная ошибка на aliens_data: 0.0233
# Средняя ошибка на aliens_data: 0.0559
# Минимальная ошибка на aliens_data: 0.0298
# Средняя ошибка на aliens_data: 0.0498
# Минимальная ошибка на aliens_data: 0.0498
# Средняя ошибка на aliens_data: 0.0354
# Минимальная ошибка на aliens_data: 0.0336
# Средняя ошибка на aliens_data: 0.0383
# Минимальная ошибка на aliens_data: 0.0362
# Средняя ошибка на aliens_data: 0.0705
# Минимальная ошибка на aliens_data: 0.0639
# Средняя ошибка на aliens_data: 0.0522
# Минимальная ошибка на aliens_data: 0.0476
# Средняя ошибка на aliens_data: 0.0703
# Минимальная ошибка на aliens_data: 0.0514
# Средняя ошибка на aliens_data: 0.0432
# Минимальная ошибка на aliens_data: 0.0367
# Средняя ошибка на aliens_data: 0.0555
# Минимальная ошибка на aliens_data: 0.0523
# Средняя ошибка на aliens_data: 0.0545
# Минимальная ошибка на aliens_data: 0.0511
# Средняя ошибка на aliens_data: 0.0341
# Минимальная ошибка на aliens_data: 0.0146
# Средняя ошибка на aliens_data: 0.048
# Минимальная ошибка на aliens_data: 0.0318
# Средняя ошибка на aliens_data: 0.0384
# Минимальная ошибка на aliens_data: 0.0376
# Средняя ошибка на aliens_data: 0.0286
# Минимальная ошибка на aliens_data: 0.0203
# Средняя ошибка на aliens_data: 0.06
# Минимальная ошибка на aliens_data: 0.0389
# Средняя ошибка на aliens_data: 0.056
# Минимальная ошибка на aliens_data: 0.0354
# Средняя ошибка на aliens_data: 0.0447
# Минимальная ошибка на aliens_data: 0.0359
# Средняя ошибка на aliens_data: 0.0975
# Минимальная ошибка на aliens_data: 0.0914
# Средняя ошибка на aliens_data: 0.0906
# Минимальная ошибка на aliens_data: 0.0421
# Средняя ошибка на aliens_data: 0.0732
# Минимальная ошибка на aliens_data: 0.0473
# Средняя ошибка на aliens_data: 0.0518
# Минимальная ошибка на aliens_data: 0.0292
# Средняя ошибка на aliens_data: 0.0353
# Минимальная ошибка на aliens_data: 0.0198
# Средняя ошибка на aliens_data: 0.0644
# Минимальная ошибка на aliens_data: 0.0571
# Средняя ошибка на aliens_data: 0.0391
# Минимальная ошибка на aliens_data: 0.0345
# Средняя ошибка на aliens_data: 0.0749
# Минимальная ошибка на aliens_data: 0.0453
# Средняя ошибка на aliens_data: 0.0693
# Минимальная ошибка на aliens_data: 0.0545
# Средняя ошибка на aliens_data: 0.0665
# Минимальная ошибка на aliens_data: 0.0464
# Средняя ошибка на aliens_data: 0.047
# Минимальная ошибка на aliens_data: 0.0294
# Средняя ошибка на aliens_data: 0.0808
# Минимальная ошибка на aliens_data: 0.0591
# Средняя ошибка на aliens_data: 0.0418
# Минимальная ошибка на aliens_data: 0.0368
# Средняя ошибка на aliens_data: 0.0654
# Минимальная ошибка на aliens_data: 0.0447
# Средняя ошибка на aliens_data: 0.0581
# Минимальная ошибка на aliens_data: 0.0557
# Средняя ошибка на aliens_data: 0.0601
# Минимальная ошибка на aliens_data: 0.0587
# Средняя ошибка на aliens_data: 0.0396
# Минимальная ошибка на aliens_data: 0.0289
# Средняя ошибка на aliens_data: 0.0567
# Минимальная ошибка на aliens_data: 0.0323
# Средняя ошибка на aliens_data: 0.0771
# Минимальная ошибка на aliens_data: 0.0513
# Средняя ошибка на aliens_data: 0.1081
# Минимальная ошибка на aliens_data: 0.0538
# кадров с лицами (5834, 408, 720, 3)
# время людей на видео:  4.2  минут
# время обработки 2212.979093313217

# %%
np_cutfilm = np.array(np_cutfilm)
np_cutfilm.shape
# Out:
# (9, 408, 720, 3)

# %%
fps_of_video
# Out:
# 23

# %% [markdown]
# Сборка их массива видео с imageio

# %%
import imageio
path_videopersons = '/content/drive/MyDrive/Colab Bases/Команда УИИ/fromtest_simpleMSE_0.07.mp4'
fps_of_video = int(cv2.VideoCapture(path_cut_vidio).get(cv2.CAP_PROP_FPS))
frames = np_cutfilm
imageio.mimsave(path_videopersons, frames, fps=fps_of_video)
# Out:
# WARNING:root:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (408, 720) to (416, 720) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to None (risking incompatibility). You may also see a FFMPEG warning concerning speedloss due to data not being aligned.

# %% [markdown]
# Долго с этим промучился, синия выходит! Пока не нашел на основ CV2

# %%
np.save('/content/drive/MyDrive/Colab Bases/Команда УИИ/set_frame_simpleMSE_0.07.npy', set_frame)
np.save('/content/drive/MyDrive/Colab Bases/Команда УИИ/np_cutfilm_simpleMSE_0.07.npy',np_cutfilm)

# %%
pred_img = train_model.predict([xVal]) # сделаем предикт для первых ста картинок лиц
predsign = predsign * 255 # представляем в виде значений от 0 до 255
predsign = predsign.astype('uint8') # устанавливаем 8битовый тип
plotImages(test_signs[:2]*255, predsign)

# %% [markdown]
# # Еще проверка на основе Unet

# %%
from tensorflow.keras import layers


def get_model(img_size, num_classes):
    inputs = Input(shape=img_size + (3,))

    ### [First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [64, 128, 256]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(filters, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    ### [Second half of the network: upsampling inputs] ###

    for filters in [256, 128, 64, 32]:
        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.UpSampling2D(2)(x)

        # Project residual
        residual = layers.UpSampling2D(2)(previous_block_activation)
        residual = layers.Conv2D(filters, 1, padding="same")(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Add a per-pixel classification layer
    outputs = layers.Conv2D(num_classes, 3, activation="softmax", padding="same")(x)

    # Define the model
    model = Model(inputs, outputs)
    return model

img_size = (128,128)
num_classes = 3
# Free up RAM in case the model definition cells were run multiple times
#keras.backend.clear_session()

# Build model
model_U = get_model(img_size, num_classes)
model_U.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_20 (InputLayer)           [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 64, 64, 32)   896         input_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 64, 64, 32)   128         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 32)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 32)   0           activation_15[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 64, 64, 64)   2400        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 64, 64, 64)   256         separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 64)   0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 64, 64, 64)   4736        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 64, 64, 64)   256         separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 64)   0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 32, 32, 64)   2112        activation_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 64)   0           max_pooling2d_3[0][0]
#                                                                  conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 32, 64)   0           add_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_8 (SeparableCo (None, 32, 32, 128)  8896        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 32, 32, 128)  512         separable_conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 128)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_9 (SeparableCo (None, 32, 32, 128)  17664       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 32, 32, 128)  512         separable_conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 128)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 16, 16, 128)  8320        add_7[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 128)  0           max_pooling2d_4[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 16, 128)  0           add_8[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_10 (SeparableC (None, 16, 16, 256)  34176       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 16, 16, 256)  1024        separable_conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 256)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_11 (SeparableC (None, 16, 16, 256)  68096       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 16, 16, 256)  1024        separable_conv2d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 8, 8, 256)    0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 256)    33024       add_8[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 256)    0           max_pooling2d_5[0][0]
#                                                                  conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 8, 8, 256)    0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 8, 8, 256)    590080      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 256)    1024        conv2d_transpose_16[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 256)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 8, 8, 256)    590080      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 8, 8, 256)    1024        conv2d_transpose_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 16, 16, 256)  0           add_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 16, 16, 256)  0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 16, 16, 256)  65792       up_sampling2d_9[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 256)  0           up_sampling2d_8[0][0]
#                                                                  conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 256)  0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 16, 16, 128)  295040      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 16, 16, 128)  512         conv2d_transpose_18[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 128)  0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, 16, 16, 128)  147584      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 16, 16, 128)  512         conv2d_transpose_19[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 32, 32, 256)  0           add_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 32, 32, 128)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 32, 32, 128)  32896       up_sampling2d_11[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 32, 32, 128)  0           up_sampling2d_10[0][0]
#                                                                  conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 32, 128)  0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, 32, 32, 64)   73792       activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 32, 32, 64)   256         conv2d_transpose_20[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 64)   0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 32, 32, 64)   36928       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 32, 32, 64)   256         conv2d_transpose_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 64, 64, 128)  0           add_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 64, 64, 64)   0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 64, 64, 64)   8256        up_sampling2d_13[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 64, 64, 64)   0           up_sampling2d_12[0][0]
#                                                                  conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 64, 64, 64)   0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 64, 64, 32)   18464       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 64, 64, 32)   128         conv2d_transpose_22[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 64, 64, 32)   0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 64, 64, 32)   9248        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 64, 64, 32)   128         conv2d_transpose_23[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 128, 128, 64) 0           add_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 128, 128, 32) 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 128, 128, 32) 2080        up_sampling2d_15[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 128, 128, 32) 0           up_sampling2d_14[0][0]
#                                                                  conv2d_82[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 128, 128, 3)  867         add_13[0][0]
# ==================================================================================================
# Total params: 2,058,979
# Trainable params: 2,055,203
# Non-trainable params: 3,776
# __________________________________________________________________________________________________

# %%
 model_U.compile(optimizer=Adam(lr=0.0001), loss='mse', metrics=['accuracy']) # компилируем модель также, с выбором оптимайзера и среднеквадратичной ошибки
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
epochs = 15  # число эпох для обучения
patienceStop = round(epochs/5)  #через сколько эпох остановим обучение, если нет развития
patienceReduce = round(epochs/25) #через сколько эпох понизим lr (шаг обучения)
# функция для колбека по понижению lr
reduce_lr = ReduceLROnPlateau(verbose=1, monitor='val_accuracy',patience=patienceReduce,min_lr=0.000001,factor=0.3)
# функция для остановки обучения и сохранения лучших весов
earlystopper = EarlyStopping(patience=patienceStop, verbose=1, monitor='val_accuracy',restore_best_weights=True)

# %%
#обучаем сеть
result_U = model_U.fit(xTrain, xTrain,
                   batch_size=36,
                   epochs = epochs,
                   validation_data=(xVal, xVal),
                   verbose=1,
                   callbacks=[reduce_lr, earlystopper]) # добавляем наши колбеки
# Out:
# Epoch 1/15
# 7/7 [==============================] - 36s 5s/step - loss: 0.1303 - accuracy: 0.6827 - val_loss: 0.0374 - val_accuracy: 0.9463
# Epoch 2/15
# 7/7 [==============================] - 36s 5s/step - loss: 0.1285 - accuracy: 0.6634 - val_loss: 0.0399 - val_accuracy: 0.9443
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 3/15
# 7/7 [==============================] - 36s 5s/step - loss: 0.1265 - accuracy: 0.6382 - val_loss: 0.0420 - val_accuracy: 0.9413
# Epoch 4/15
# 7/7 [==============================] - 36s 5s/step - loss: 0.1254 - accuracy: 0.6336 - val_loss: 0.0437 - val_accuracy: 0.9379
# Restoring model weights from the end of the best epoch.
# Epoch 00004: early stopping

# %%
model_U.save('/content/drive/MyDrive/Colab Bases/Команда УИИ/model_U_1.h5')
model_U.save_weights('/content/drive/MyDrive/Colab Bases/Команда УИИ/weights_model_U_1.h5')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# Но Unet в итог не так хорошо обучалась, как АС выдуманный
